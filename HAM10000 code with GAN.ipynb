# %%
import numpy as np
import pandas as pd
import io
import os
import time
import tensorflow as tf
from PIL import Image
from glob import glob
import itertools

import plotly.graph_objects as go
import plotly.express as px
from plotly.subplots import make_subplots
import matplotlib.pyplot as plt
import seaborn as sns

import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Conv2D, Flatten, BatchNormalization, Dropout, Dense, MaxPool2D, GlobalAveragePooling2D, Input
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping, ModelCheckpoint
from tensorflow.keras.applications import ResNet50, ResNet101, EfficientNetB0
from tensorflow.keras.optimizers import Adam

from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, precision_recall_fscore_support
from sklearn.utils.class_weight import compute_class_weight

# Optional imports for enhanced features
try:
    import cv2
    CV2_AVAILABLE = True
except ImportError:
    CV2_AVAILABLE = False
    print("OpenCV not available. Some image processing features will be limited.")

# Configuration
class Config:
    """Configuration settings for the skin cancer classification pipeline"""
    # Image settings
    IMAGE_SIZE = 224  # Standard size for medical images
    BATCH_SIZE = 16   # Reduced batch size for stability
    EPOCHS = 5        # Reduced epochs as requested
    
    # Data paths
    BASE_DIR = r"C:\Users\abdur\vs_code\Sidra-Tasks\sidra thesis\Research Methadology Project-20250403T120511Z-0011\Research Methadology Project\Datasets\HAMM"
    
    # Model settings
    LEARNING_RATE = 0.0001  # Much lower learning rate
    DROPOUT_RATE = 0.5      # Higher dropout to prevent overfitting
    
    # Training settings
    VALIDATION_SPLIT = 0.2
    TEST_SPLIT = 0.2
    PATIENCE = 3            # Reduced patience

config = Config()

def setup_gpu():
    """Configure GPU memory growth if available"""
    gpus = tf.config.experimental.list_physical_devices('GPU')
    if gpus:
        try:
            for gpu in gpus:
                tf.config.experimental.set_memory_growth(gpu, True)
            print(f"GPU memory growth enabled for {len(gpus)} GPU(s)")
        except RuntimeError as e:
            print(f"GPU configuration error: {e}")
    else:
        print("No GPU found. Using CPU.")

def create_label_mappings():
    """Create label mappings for skin cancer types"""
    lesion_type_dict = {
        'nv': 'Melanocytic nevi (nv)',
        'mel': 'Melanoma (mel)',
        'bkl': 'Benign keratosis-like lesions (bkl)',
        'bcc': 'Basal cell carcinoma (bcc)',
        'akiec': 'Actinic keratoses (akiec)',
        'vasc': 'Vascular lesions (vasc)',
        'df': 'Dermatofibroma (df)'
    }
    
    label_mapping = {
        0: 'nv',
        1: 'mel',
        2: 'bkl',
        3: 'bcc',
        4: 'akiec',
        5: 'vasc',
        6: 'df'
    }
    
    reverse_label_mapping = {value: key for key, value in label_mapping.items()}
    
    return lesion_type_dict, label_mapping, reverse_label_mapping

def load_image_paths(base_dir):
    """Load image paths from the dataset directory"""
    image_folder = os.path.join(base_dir, "skin-cancer-mnist-ham10000")
    
    # Use glob to find all .jpg files in both subfolders
    imageid_path_dict = {
        os.path.splitext(os.path.basename(x))[0]: x
        for x in glob(os.path.join(image_folder, "*", "*.jpg"))
    }
    
    print(f"Total images found: {len(imageid_path_dict)}")
    return imageid_path_dict

def enhanced_load_image_pixels(image_path, target_size=224):
    """Load and preprocess image with proper medical image handling"""
    if not image_path or not os.path.exists(image_path):
        return None
    
    try:
        # Load image
        image = Image.open(image_path)
        
        # Convert to RGB if needed
        if image.mode != 'RGB':
            image = image.convert('RGB')
        
        # Resize to target size with high-quality resampling
        image = image.resize((target_size, target_size), Image.LANCZOS)
        
        # Convert to numpy array
        img_array = np.asarray(image)
        
        # Optional: Apply basic preprocessing for medical images
        if CV2_AVAILABLE:
            img_array = enhance_medical_image(img_array)
        
        return img_array
        
    except Exception as e:
        print(f"Error loading image {image_path}: {e}")
        return None

def enhance_medical_image(image):
    """Apply medical-specific image enhancement"""
    if not CV2_AVAILABLE:
        return image
    
    # Convert to LAB color space for better contrast enhancement
    lab = cv2.cvtColor(image, cv2.COLOR_RGB2LAB)
    
    # Apply CLAHE to L channel
    clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8, 8))
    lab[:, :, 0] = clahe.apply(lab[:, :, 0])
    
    # Convert back to RGB
    enhanced = cv2.cvtColor(lab, cv2.COLOR_LAB2RGB)
    
    return enhanced

def load_and_preprocess_data(base_dir):
    """Load and preprocess the HAM10000 dataset"""
    print("Loading HAM10000 dataset...")
    
    # Load image paths
    imageid_path_dict = load_image_paths(base_dir)
    
    # Load metadata
    metadata_path = os.path.join(base_dir, "HAM10000_metadata.csv")
    data = pd.read_csv(metadata_path)
    
    # Handle missing values
    data['age'].fillna(value=int(data['age'].mean()), inplace=True)
    data['age'] = data['age'].astype('int32')
    
    # Create label mappings
    lesion_type_dict, label_mapping, reverse_label_mapping = create_label_mappings()
    
    # Add cell type and path columns
    data['cell_type'] = data['dx'].map(lesion_type_dict.get)
    data['path'] = data['image_id'].map(imageid_path_dict.get)
    
    # Load image pixels with proper size
    print(f"Loading images at {config.IMAGE_SIZE}x{config.IMAGE_SIZE} resolution...")
    data['image_pixel'] = data['path'].apply(
        lambda x: enhanced_load_image_pixels(x, config.IMAGE_SIZE)
    )
    
    # Remove rows with failed image loading
    initial_count = len(data)
    data = data[data['image_pixel'].notnull()]
    final_count = len(data)
    print(f"Successfully loaded {final_count}/{initial_count} images")
    
    # Add numeric labels
    data['label'] = data['dx'].map(reverse_label_mapping.get)
    
    return data, lesion_type_dict, label_mapping, reverse_label_mapping

def analyze_class_distribution(data):
    """Analyze and visualize class distribution"""
    print("\n=== Class Distribution Analysis ===")
    
    class_counts = data['dx'].value_counts()
    print("Original class distribution:")
    for dx, count in class_counts.items():
        print(f"{dx}: {count} images")
    
    # Visualize distribution
    plt.figure(figsize=(12, 6))
    
    plt.subplot(1, 2, 1)
    class_counts.plot(kind='bar')
    plt.title('Original Class Distribution')
    plt.xlabel('Diagnosis')
    plt.ylabel('Number of Images')
    plt.xticks(rotation=45)
    
    plt.subplot(1, 2, 2)
    plt.pie(class_counts.values, labels=class_counts.index, autopct='%1.1f%%')
    plt.title('Class Distribution (Percentage)')
    
    plt.tight_layout()
    plt.show()
    
    return class_counts

def create_balanced_dataset_smart(data):
    """Create balanced dataset using smart augmentation"""
    print("\n=== Creating Balanced Dataset ===")
    
    class_counts = data['dx'].value_counts()
    max_count = class_counts.max()
    
    print(f"Target count per class: {max_count}")
    
    balanced_frames = []
    
    for dx in class_counts.index:
        class_data = data[data['dx'] == dx].copy()
        current_count = len(class_data)
        
        if current_count < max_count:
            # Calculate how many more samples we need
            needed = max_count - current_count
            
            # Use smart sampling instead of simple duplication
            additional_samples = create_additional_samples(class_data, needed)
            balanced_frames.append(pd.concat([class_data, additional_samples], ignore_index=True))
            
            print(f"Class {dx}: {current_count} -> {len(balanced_frames[-1])} (+{needed})")
        else:
            balanced_frames.append(class_data)
            print(f"Class {dx}: {current_count} (no augmentation needed)")
    
    # Combine all balanced data
    balanced_data = pd.concat(balanced_frames, ignore_index=True)
    
    print(f"\nFinal balanced dataset: {len(balanced_data)} images")
    
    return balanced_data

def create_additional_samples(class_data, needed_count):
    """Create additional samples using intelligent duplication with variation"""
    additional_samples = []
    
    # Sample with replacement but add some variation
    for i in range(needed_count):
        # Select a random sample from the class
        sample_idx = np.random.randint(0, len(class_data))
        sample = class_data.iloc[sample_idx].copy()
        
        # Add slight variation to avoid exact duplicates
        if sample['image_pixel'] is not None:
            # Apply random augmentation to the image
            augmented_image = apply_random_augmentation(sample['image_pixel'])
            sample['image_pixel'] = augmented_image
        
        additional_samples.append(sample)
    
    return pd.DataFrame(additional_samples)

def apply_random_augmentation(image):
    """Apply random augmentation to an image"""
    if not CV2_AVAILABLE:
        return image
    
    # Random rotation (-10 to 10 degrees)
    angle = np.random.uniform(-10, 10)
    height, width = image.shape[:2]
    center = (width // 2, height // 2)
    rotation_matrix = cv2.getRotationMatrix2D(center, angle, 1.0)
    rotated = cv2.warpAffine(image, rotation_matrix, (width, height))
    
    # Random brightness adjustment
    brightness = np.random.uniform(0.8, 1.2)
    brightened = np.clip(rotated * brightness, 0, 255).astype(np.uint8)
    
    # Random horizontal flip
    if np.random.random() > 0.5:
        brightened = cv2.flip(brightened, 1)
    
    return brightened

def prepare_data_for_training(data):
    """Prepare data for model training - FIXED VERSION"""
    print("\n=== Preparing Data for Training ===")
    
    # Convert image pixels to numpy array
    X = np.stack(data['image_pixel'].values)
    y = np.array(data['label'].values)
    
    print(f"X shape: {X.shape}")
    print(f"y shape: {y.shape}")
    print(f"Unique labels: {np.unique(y)}")
    print(f"Label distribution: {np.bincount(y)}")
    
    # Split data with stratification
    X_train, X_test, y_train, y_test = train_test_split(
        X, y, test_size=config.TEST_SPLIT, random_state=42, stratify=y
    )
    
    print(f"Training set: {X_train.shape[0]} samples")
    print(f"Test set: {X_test.shape[0]} samples")
    
    # Normalize data manually
    X_train = X_train.astype(np.float32) / 255.0
    X_test = X_test.astype(np.float32) / 255.0
    
    # Create simple data generators with minimal augmentation
    train_datagen = ImageDataGenerator(
        rotation_range=10,
        width_shift_range=0.05,
        height_shift_range=0.05,
        horizontal_flip=True,
        validation_split=config.VALIDATION_SPLIT
    )
    
    # Fit the generator
    train_datagen.fit(X_train)
    
    return X_train, X_test, y_train, y_test, train_datagen
EPOCHS = 100

def create_custom_cnn():
    model = Sequential([
        Conv2D(32, (3, 3), activation='relu', input_shape=(config.IMAGE_SIZE, config.IMAGE_SIZE, 3)),
        BatchNormalization(),
        MaxPool2D(2, 2),
        Conv2D(64, (3, 3), activation='relu'),
        BatchNormalization(),
        MaxPool2D(2, 2),
        Conv2D(128, (3, 3), activation='relu'),
        BatchNormalization(),
        MaxPool2D(2, 2),
        Conv2D(256, (3, 3), activation='relu'),
        BatchNormalization(),
        MaxPool2D(2, 2),
        GlobalAveragePooling2D(),
        Dropout(config.DROPOUT_RATE),
        Dense(256, activation='relu'),
        Dropout(config.DROPOUT_RATE),
        Dense(7, activation='softmax')
    ])
    return model

def create_resnet50():
    base_model = ResNet50(weights='imagenet', include_top=False, input_shape=(config.IMAGE_SIZE, config.IMAGE_SIZE, 3))
    for layer in base_model.layers[-10:]:
        layer.trainable = True
    model = Sequential([
        base_model,
        GlobalAveragePooling2D(),
        Dropout(config.DROPOUT_RATE),
        Dense(256, activation='relu'),
        Dropout(config.DROPOUT_RATE),
        Dense(7, activation='softmax')
    ])
    return model

def create_resnet101():
    base_model = ResNet101(weights='imagenet', include_top=False, input_shape=(config.IMAGE_SIZE, config.IMAGE_SIZE, 3))
    for layer in base_model.layers[-15:]:
        layer.trainable = True
    model = Sequential([
        base_model,
        GlobalAveragePooling2D(),
        Dropout(config.DROPOUT_RATE),
        Dense(256, activation='relu'),
        Dropout(config.DROPOUT_RATE),
        Dense(7, activation='softmax')
    ])
    return model

def create_efficientnet():
    base_model = EfficientNetB0(weights='imagenet', include_top=False, input_shape=(config.IMAGE_SIZE, config.IMAGE_SIZE, 3))
    for layer in base_model.layers[-20:]:
        layer.trainable = True
    model = Sequential([
        base_model,
        GlobalAveragePooling2D(),
        Dropout(config.DROPOUT_RATE),
        Dense(256, activation='relu'),
        Dropout(config.DROPOUT_RATE),
        Dense(7, activation='softmax')
    ])
    return model

def compile_model(model):
    model.compile(
        optimizer=Adam(learning_rate=0.001),
        loss='sparse_categorical_crossentropy',
        metrics=['accuracy']
    )
    return model

def prepare_data_for_training(data):
    """Memory-efficient data preparation using generators"""
    print("\n=== Preparing Data for Training (Memory Efficient) ===")
    
    train_data, test_data = train_test_split(
        data, test_size=config.TEST_SPLIT, random_state=42, stratify=data['label']
    )
    
    print(f"Training set: {len(train_data)} samples")
    print(f"Test set: {len(test_data)} samples")
    
    train_datagen = ImageDataGenerator(
        rescale=1.0/255.0,
        rotation_range=10,
        width_shift_range=0.05,
        height_shift_range=0.05,
        horizontal_flip=True,
        validation_split=config.VALIDATION_SPLIT
    )
    
    test_datagen = ImageDataGenerator(rescale=1.0/255.0)
    
    return train_data, test_data, train_datagen, test_datagen

def create_custom_generator(data, batch_size=16, target_size=(224, 224)):
    """Custom generator that loads images on demand"""
    while True:
        indices = np.random.permutation(len(data))
        for i in range(0, len(data), batch_size):
            batch_indices = indices[i:i+batch_size]
            batch_data = data.iloc[batch_indices]
            
            batch_x = []
            batch_y = []
            
            for _, row in batch_data.iterrows():
                img = enhanced_load_image_pixels(row['path'], target_size[0])
                if img is not None:
                    batch_x.append(img)
                    batch_y.append(row['label'])
            
            if len(batch_x) > 0:
                batch_x = np.array(batch_x).astype(np.float32) / 255.0
                batch_y = np.array(batch_y)
                yield batch_x, batch_y

def train_and_evaluate_model(model, model_name, train_data, test_data, train_datagen, test_datagen):
    print(f"\n{'='*50}")
    print(f"Training {model_name}")
    print(f"{'='*50}")
    
    train_steps = len(train_data) // config.BATCH_SIZE
    val_steps = int(train_steps * config.VALIDATION_SPLIT)
    test_steps = len(test_data) // config.BATCH_SIZE
    
    train_generator = create_custom_generator(train_data, config.BATCH_SIZE)
    val_generator = create_custom_generator(train_data.sample(int(len(train_data) * config.VALIDATION_SPLIT)), config.BATCH_SIZE)
    test_generator = create_custom_generator(test_data, config.BATCH_SIZE)
    
    early_stopping = EarlyStopping(
        monitor='val_loss',
        patience=8,
        restore_best_weights=True,
        verbose=1
    )
    
    reduce_lr = ReduceLROnPlateau(
        monitor='val_loss',
        factor=0.5,
        patience=5,
        min_lr=1e-7,
        verbose=1
    )
    
    start_time = time.time()
    history = model.fit(
        train_generator,
        steps_per_epoch=train_steps,
        epochs=EPOCHS,
        validation_data=val_generator,
        validation_steps=val_steps,
        callbacks=[early_stopping, reduce_lr],
        verbose=1
    )
    training_time = time.time() - start_time
    
    start_time = time.time()
    test_loss, test_accuracy = model.evaluate(test_generator, steps=test_steps, verbose=0)
    
    y_pred_list = []
    y_true_list = []
    for i, (batch_x, batch_y) in enumerate(test_generator):
        if i >= test_steps:
            break
        batch_pred = model.predict(batch_x, verbose=0)
        y_pred_list.extend(np.argmax(batch_pred, axis=1))
        y_true_list.extend(batch_y)
    
    y_pred = np.array(y_pred_list)
    y_test = np.array(y_true_list)
    testing_time = time.time() - start_time
    
    cm = confusion_matrix(y_test, y_pred)
    cm_percentage = (cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]) * 100
    
    print(f"\nTraining Time: {training_time:.2f} seconds")
    print(f"Testing Time: {testing_time:.2f} seconds")
    print(f"Test Accuracy: {test_accuracy:.3f}")
    
    print(f"\nConfusion Matrix (Percentage) for {model_name}:")
    print(cm_percentage)
    
    report = classification_report(y_test, y_pred, digits=3)
    print(f"\nClassification Report for {model_name}:")
    print(report)
    
    plt.figure(figsize=(15, 5))
    
    plt.subplot(1, 3, 1)
    epochs_range = range(1, len(history.history['loss']) + 1)
    plt.plot(epochs_range, history.history['loss'], 'bo-', label='Training Loss')
    plt.plot(epochs_range, history.history['val_loss'], 'ro-', label='Validation Loss')
    plt.title(f'{model_name} - Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True)
    
    plt.subplot(1, 3, 2)
    plt.plot(epochs_range, history.history['accuracy'], 'bo-', label='Training Accuracy')
    plt.plot(epochs_range, history.history['val_accuracy'], 'ro-', label='Validation Accuracy')
    plt.title(f'{model_name} - Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.grid(True)
    
    plt.subplot(1, 3, 3)
    sns.heatmap(cm_percentage, annot=True, fmt='.1f', cmap='Blues')
    plt.title(f'{model_name} - Confusion Matrix (%)')
    plt.ylabel('True Label')
    plt.xlabel('Predicted Label')
    
    plt.tight_layout()
    plt.show()
    
    del model
    tf.keras.backend.clear_session()
    import gc
    gc.collect()
    
    return history, training_time, testing_time, test_accuracy

train_data, test_data, train_datagen, test_datagen = prepare_data_for_training(balanced_data)

models_config = [
    (create_custom_cnn, "Custom CNN"),
    (create_resnet50, "ResNet50"),
    (create_resnet101, "ResNet101"),
    (create_efficientnet, "EfficientNet-B0")
]

results = {}

for model_func, model_name in models_config:
    model = compile_model(model_func())
    history, train_time, test_time, test_acc = train_and_evaluate_model(
        model, model_name, train_data, test_data, train_datagen, test_datagen
    )
    results[model_name] = {
        'history': history,
        'train_time': train_time,
        'test_time': test_time,
        'test_accuracy': test_acc
    }

print(f"\n{'='*60}")
print("SUMMARY OF ALL MODELS")
print(f"{'='*60}")
for name, result in results.items():
    print(f"{name:15} | Accuracy: {result['test_accuracy']:.3f} | Train Time: {result['train_time']:.2f}s | Test Time: {result['test_time']:.2f}s")

# %%
import numpy as np
import pandas as pd
import os
import time
import tensorflow as tf
from PIL import Image, ImageFilter
from glob import glob
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, BatchNormalization, Dropout, Conv2D, Conv2DTranspose, Reshape, LeakyReLU, LayerNormalization, Flatten, Input
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import train_test_split
import gc
import random

tf.random.set_seed(42)
np.random.seed(42)
random.seed(42)

class Config:
    IMAGE_SIZE = 224
    BATCH_SIZE = 16
    BASE_DIR = r"C:\Users\abdur\vs_code\Sidra-Tasks\sidra thesis\Research Methadology Project-20250403T120511Z-0011\Research Methadology Project\Datasets\HAMM"
    VALIDATION_SPLIT = 0.2
    TEST_SPLIT = 0.2
    
    GAN_IMAGE_SIZE = 64
    GAN_BATCH_SIZE = 4
    LATENT_DIM = 100
    GAN_EPOCHS = 1000

config = Config()

def clear_memory():
    gc.collect()
    tf.keras.backend.clear_session()
    print("Memory cleared")

def setup_gpu():
    gpus = tf.config.experimental.list_physical_devices('GPU')
    if gpus:
        try:
            for gpu in gpus:
                tf.config.experimental.set_memory_growth(gpu, True)
            print(f"GPU memory growth enabled for {len(gpus)} GPU(s)")
        except RuntimeError as e:
            print(f"GPU configuration error: {e}")
    else:
        print("No GPU found. Using CPU.")

def create_label_mappings():
    lesion_type_dict = {
        'nv': 'Melanocytic nevi (nv)',
        'mel': 'Melanoma (mel)',
        'bkl': 'Benign keratosis-like lesions (bkl)',
        'bcc': 'Basal cell carcinoma (bcc)',
        'akiec': 'Actinic keratoses (akiec)',
        'vasc': 'Vascular lesions (vasc)',
        'df': 'Dermatofibroma (df)'
    }
    
    label_mapping = {0: 'nv', 1: 'mel', 2: 'bkl', 3: 'bcc', 4: 'akiec', 5: 'vasc', 6: 'df'}
    reverse_label_mapping = {v: k for k, v in label_mapping.items()}
    
    return lesion_type_dict, label_mapping, reverse_label_mapping

def enhanced_load_image_pixels(image_path, target_size=224):
    if not image_path or not os.path.exists(image_path):
        return None
    try:
        image = Image.open(image_path)
        if image.mode != 'RGB':
            image = image.convert('RGB')
        image = image.resize((target_size, target_size), Image.LANCZOS)
        return np.asarray(image)
    except Exception as e:
        print(f"Error loading image {image_path}: {e}")
        return None

def build_generator():
    model = tf.keras.Sequential()
    model.add(Dense(4 * 4 * 256, use_bias=False, input_shape=(config.LATENT_DIM,)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.2))
    model.add(Reshape((4, 4, 256)))
    
    model.add(Conv2DTranspose(128, (4, 4), strides=(2, 2), padding='same', use_bias=False))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.2))
    
    model.add(Conv2DTranspose(64, (4, 4), strides=(2, 2), padding='same', use_bias=False))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.2))
    
    model.add(Conv2DTranspose(32, (4, 4), strides=(2, 2), padding='same', use_bias=False))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.2))
    
    model.add(Conv2DTranspose(16, (4, 4), strides=(2, 2), padding='same', use_bias=False))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.2))
    
    model.add(Conv2D(3, (3, 3), padding='same', activation='tanh', use_bias=False))
    return model

def build_discriminator():
    inputs = Input(shape=(config.GAN_IMAGE_SIZE, config.GAN_IMAGE_SIZE, 3))
    x = Conv2D(32, (4, 4), strides=(2, 2), padding='same')(inputs)
    x = LeakyReLU(alpha=0.2)(x)
    x = Dropout(0.3)(x)
    
    x = Conv2D(64, (4, 4), strides=(2, 2), padding='same')(x)
    x = LayerNormalization()(x)
    x = LeakyReLU(alpha=0.2)(x)
    x = Dropout(0.3)(x)
    
    x = Conv2D(128, (4, 4), strides=(2, 2), padding='same')(x)
    x = LayerNormalization()(x)
    x = LeakyReLU(alpha=0.2)(x)
    x = Dropout(0.3)(x)
    
    x = Flatten()(x)
    outputs = Dense(1)(x)
    return tf.keras.Model(inputs=inputs, outputs=outputs)

def gradient_penalty(discriminator, real_images, fake_images, batch_size):
    alpha = tf.random.uniform([batch_size, 1, 1, 1], 0.0, 1.0)
    diff = fake_images - real_images
    interpolated = real_images + alpha * diff
    
    with tf.GradientTape() as gp_tape:
        gp_tape.watch(interpolated)
        pred = discriminator(interpolated, training=True)
    
    grads = gp_tape.gradient(pred, [interpolated])[0]
    norm = tf.sqrt(tf.reduce_sum(tf.square(grads), axis=[1, 2, 3]))
    return tf.reduce_mean((norm - 1.0) ** 2)

class WGANGP(tf.keras.Model):
    def __init__(self, generator, discriminator, latent_dim, gp_weight=10.0):
        super(WGANGP, self).__init__()
        self.generator = generator
        self.discriminator = discriminator
        self.latent_dim = latent_dim
        self.gp_weight = gp_weight
        
    def compile(self, d_optimizer, g_optimizer):
        super(WGANGP, self).compile()
        self.d_optimizer = d_optimizer
        self.g_optimizer = g_optimizer
        
    def train_step(self, real_images):
        if isinstance(real_images, tuple):
            real_images = real_images[0]
        batch_size = tf.shape(real_images)[0]
        
        for i in range(2):
            random_latent_vectors = tf.random.normal(shape=(batch_size, self.latent_dim))
            with tf.GradientTape() as tape:
                fake_images = self.generator(random_latent_vectors, training=True)
                real_logits = self.discriminator(real_images, training=True)
                fake_logits = self.discriminator(fake_images, training=True)
                d_cost = tf.reduce_mean(fake_logits) - tf.reduce_mean(real_logits)
                gp = gradient_penalty(self.discriminator, real_images, fake_images, batch_size)
                d_loss = d_cost + gp * self.gp_weight
            
            d_gradient = tape.gradient(d_loss, self.discriminator.trainable_variables)
            self.d_optimizer.apply_gradients(zip(d_gradient, self.discriminator.trainable_variables))
        
        random_latent_vectors = tf.random.normal(shape=(batch_size, self.latent_dim))
        with tf.GradientTape() as tape:
            generated_images = self.generator(random_latent_vectors, training=True)
            gen_img_logits = self.discriminator(generated_images, training=True)
            g_loss = -tf.reduce_mean(gen_img_logits)
            
        gen_gradient = tape.gradient(g_loss, self.generator.trainable_variables)
        self.g_optimizer.apply_gradients(zip(gen_gradient, self.generator.trainable_variables))
        
        return {"d_loss": d_loss, "g_loss": g_loss}

def train_gan_for_class(class_data, class_code):
    print(f"Training GAN for class {class_code}...")
    
    images = []
    max_images = min(50, len(class_data))
    for _, row in class_data.head(max_images).iterrows():
        img = enhanced_load_image_pixels(row['path'], config.GAN_IMAGE_SIZE)
        if img is not None:
            images.append(img)
    
    if len(images) < 5:
        print(f"Not enough images for {class_code}, skipping GAN training")
        return None
    
    images = np.array(images).astype('float32')
    images = (images - 127.5) / 127.5
    
    dataset = tf.data.Dataset.from_tensor_slices(images)
    dataset = dataset.shuffle(50).batch(config.GAN_BATCH_SIZE, drop_remainder=True)
    
    with tf.device('/GPU:0'):
        generator = build_generator()
        discriminator = build_discriminator()
        wgan = WGANGP(generator, discriminator, config.LATENT_DIM)
        
        g_optimizer = Adam(learning_rate=0.0002, beta_1=0.5, beta_2=0.9)
        d_optimizer = Adam(learning_rate=0.0002, beta_1=0.5, beta_2=0.9)
        wgan.compile(d_optimizer=d_optimizer, g_optimizer=g_optimizer)
        
        for epoch in range(config.GAN_EPOCHS):
            for batch in dataset:
                wgan.train_step(batch)
            if (epoch + 1) % 10 == 0:
                print(f"Class {class_code} - Epoch {epoch+1}/{config.GAN_EPOCHS}")
                
                # Generate sample images during training to monitor quality
                if epoch == config.GAN_EPOCHS - 1:  # Only at the end
                    sample_noise = tf.random.normal([9, config.LATENT_DIM])
                    sample_images = generator(sample_noise, training=False)
                    sample_images = ((sample_images * 127.5) + 127.5).numpy().astype(np.uint8)
                    
                    # Create sample directory
                    sample_dir = os.path.join(config.BASE_DIR, "GAN_generated_images", f"{class_code}_samples")
                    if not os.path.exists(sample_dir):
                        os.makedirs(sample_dir)
                    
                    # Save sample images
                    for i, img_array in enumerate(sample_images):
                        img = Image.fromarray(img_array)
                        img.save(os.path.join(sample_dir, f"{class_code}_sample_{i+1}.jpg"), quality=95)
                    
                    print(f"Saved 9 sample images for {class_code} to {sample_dir}")
    
    return generator

def generate_synthetic_images(generator, num_images, class_code):
    if generator is None:
        return []
    
    # Create output directory for this class
    output_dir = os.path.join(config.BASE_DIR, "GAN_generated_images", f"{class_code}_synthetic")
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)
        print(f"Created directory: {output_dir}")
    
    noise = tf.random.normal([num_images, config.LATENT_DIM])
    generated_images = generator(noise, training=False)
    generated_images = ((generated_images * 127.5) + 127.5).numpy().astype(np.uint8)
    
    synthetic_data = []
    for i, img_array in enumerate(generated_images):
        img = Image.fromarray(img_array)
        img = img.filter(ImageFilter.GaussianBlur(radius=0.3))
        
        # Save the 64x64 generated image
        img_64_path = os.path.join(output_dir, f"{class_code}_generated_64x64_{i+1}.jpg")
        img.save(img_64_path, quality=95)
        
        # Resize to 224x224 for model training
        img_resized = img.resize((config.IMAGE_SIZE, config.IMAGE_SIZE), Image.LANCZOS)
        
        # Save the 224x224 resized image
        img_224_path = os.path.join(output_dir, f"{class_code}_generated_224x224_{i+1}.jpg")
        img_resized.save(img_224_path, quality=95)
        
        synthetic_data.append({
            'image_pixel': np.asarray(img_resized),
            'dx': class_code,
            'label': None,
            'synthetic': True
        })
    
    print(f"Saved {num_images} synthetic images for class {class_code} to {output_dir}")
    return synthetic_data

def load_and_balance_data():
    print("Loading HAM10000 dataset...")
    
    image_folder = os.path.join(config.BASE_DIR, "skin-cancer-mnist-ham10000")
    imageid_path_dict = {
        os.path.splitext(os.path.basename(x))[0]: x
        for x in glob(os.path.join(image_folder, "*", "*.jpg"))
    }
    print(f"Total images found: {len(imageid_path_dict)}")
    
    metadata_path = os.path.join(config.BASE_DIR, "HAM10000_metadata.csv")
    data = pd.read_csv(metadata_path)
    data['age'].fillna(value=int(data['age'].mean()), inplace=True)
    
    lesion_type_dict, label_mapping, reverse_label_mapping = create_label_mappings()
    data['cell_type'] = data['dx'].map(lesion_type_dict.get)
    data['path'] = data['image_id'].map(imageid_path_dict.get)
    data = data[data['path'].notnull()]
    data['label'] = data['dx'].map(reverse_label_mapping.get)
    
    print("\n=== Class Distribution Analysis ===")
    class_counts = data['dx'].value_counts()
    for dx, count in class_counts.items():
        print(f"{dx}: {count} images")
    
    print("\n=== Creating Balanced Dataset with GAN ===")
    max_count = class_counts.max()
    print(f"Target count per class: {max_count}")
    
    balanced_data = []
    
    for dx in class_counts.index:
        class_data = data[data['dx'] == dx].copy()
        current_count = len(class_data)
        
        for _, row in class_data.iterrows():
            img = enhanced_load_image_pixels(row['path'], config.IMAGE_SIZE)
            if img is not None:
                balanced_data.append({
                    'image_pixel': img,
                    'dx': dx,
                    'label': reverse_label_mapping[dx],
                    'synthetic': False
                })
        
        if current_count < max_count:
            needed = max_count - current_count
            print(f"Class {dx}: {current_count} original, generating {needed} synthetic images")
            
            generator = train_gan_for_class(class_data, dx)
            synthetic_data = generate_synthetic_images(generator, needed, dx)
            
            for syn_data in synthetic_data:
                syn_data['label'] = reverse_label_mapping[dx]
                balanced_data.append(syn_data)
            
            del generator
            clear_memory()
        else:
            print(f"Class {dx}: {current_count} (no augmentation needed)")
    
    balanced_df = pd.DataFrame(balanced_data)
    print(f"\nFinal balanced dataset: {len(balanced_df)} images")
    
    return balanced_df, lesion_type_dict, label_mapping, reverse_label_mapping

def create_custom_generator(data, batch_size=16):
    while True:
        indices = np.random.permutation(len(data))
        for i in range(0, len(data), batch_size):
            batch_indices = indices[i:i+batch_size]
            batch_data = data.iloc[batch_indices]
            
            batch_x = []
            batch_y = []
            
            for _, row in batch_data.iterrows():
                if row['image_pixel'] is not None:
                    batch_x.append(row['image_pixel'])
                    batch_y.append(row['label'])
            
            if len(batch_x) > 0:
                batch_x = np.array(batch_x).astype(np.float32) / 255.0
                batch_y = np.array(batch_y)
                yield batch_x, batch_y

setup_gpu()
balanced_data, lesion_type_dict, label_mapping, reverse_label_mapping = load_and_balance_data()

train_data, test_data = train_test_split(
    balanced_data, test_size=config.TEST_SPLIT, random_state=42, stratify=balanced_data['label']
)

print(f"\n{'='*60}")
print("DATA PREPARATION COMPLETE")
print(f"{'='*60}")
print(f"Training set: {len(train_data)} samples")
print(f"Test set: {len(test_data)} samples")
print(f"Classes available: {list(label_mapping.values())}")
print("Variables created: balanced_data, train_data, test_data, config, create_custom_generator")
print("Ready for model training!")
# Out:
# GPU memory growth enabled for 1 GPU(s)
# Loading HAM10000 dataset...
# Total images found: 4325
#
# === Class Distribution Analysis ===
# nv: 2784 images
# mel: 621 images
# bkl: 481 images
# bcc: 214 images
# akiec: 109 images
# vasc: 64 images
# df: 52 images
#
# === Creating Balanced Dataset with GAN ===
# Target count per class: 2784
# C:\Users\abdur\AppData\Local\Temp\ipykernel_26308\1087991159.py:288: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['age'].fillna(value=int(data['age'].mean()), inplace=True)
# Class nv: 2784 (no augmentation needed)
# Class mel: 621 original, generating 2163 synthetic images
# Training GAN for class mel...
# Class mel - Epoch 10/1000
# Class mel - Epoch 20/1000
# Class mel - Epoch 30/1000
# Class mel - Epoch 40/1000
# Class mel - Epoch 50/1000
# Class mel - Epoch 60/1000
# Class mel - Epoch 70/1000
# Class mel - Epoch 80/1000
# Class mel - Epoch 90/1000
# Class mel - Epoch 100/1000
# Class mel - Epoch 110/1000
# Class mel - Epoch 120/1000
# Class mel - Epoch 130/1000
# Class mel - Epoch 140/1000
# Class mel - Epoch 150/1000
# Class mel - Epoch 160/1000
# Class mel - Epoch 170/1000
# Class mel - Epoch 180/1000
# Class mel - Epoch 190/1000
# Class mel - Epoch 200/1000
# Class mel - Epoch 210/1000
# Class mel - Epoch 220/1000
# Class mel - Epoch 230/1000
# Class mel - Epoch 240/1000
# Class mel - Epoch 250/1000
# Class mel - Epoch 260/1000
# Class mel - Epoch 270/1000
# Class mel - Epoch 280/1000
# Class mel - Epoch 290/1000
# Class mel - Epoch 300/1000
# Class mel - Epoch 310/1000
# Class mel - Epoch 320/1000
# Class mel - Epoch 330/1000
# Class mel - Epoch 340/1000
# Class mel - Epoch 350/1000
# Class mel - Epoch 360/1000
# Class mel - Epoch 370/1000
# Class mel - Epoch 380/1000
# Class mel - Epoch 390/1000
# Class mel - Epoch 400/1000
# Class mel - Epoch 410/1000
# Class mel - Epoch 420/1000
# Class mel - Epoch 430/1000
# Class mel - Epoch 440/1000
# Class mel - Epoch 450/1000
# Class mel - Epoch 460/1000
# Class mel - Epoch 470/1000
# Class mel - Epoch 480/1000
# Class mel - Epoch 490/1000
# Class mel - Epoch 500/1000
# Class mel - Epoch 510/1000
# Class mel - Epoch 520/1000
# Class mel - Epoch 530/1000
# Class mel - Epoch 540/1000
# Class mel - Epoch 550/1000
# Class mel - Epoch 560/1000
# Class mel - Epoch 570/1000
# Class mel - Epoch 580/1000
# Class mel - Epoch 590/1000
# Class mel - Epoch 600/1000
# Class mel - Epoch 610/1000
# Class mel - Epoch 620/1000
# Class mel - Epoch 630/1000
# Class mel - Epoch 640/1000
# Class mel - Epoch 650/1000
# Class mel - Epoch 660/1000
# Class mel - Epoch 670/1000
# Class mel - Epoch 680/1000
# Class mel - Epoch 690/1000
# Class mel - Epoch 700/1000
# Class mel - Epoch 710/1000
# Class mel - Epoch 720/1000
# Class mel - Epoch 730/1000
# Class mel - Epoch 740/1000
# Class mel - Epoch 750/1000
# Class mel - Epoch 760/1000
# Class mel - Epoch 770/1000
# Class mel - Epoch 780/1000
# Class mel - Epoch 790/1000
# Class mel - Epoch 800/1000
# Class mel - Epoch 810/1000
# Class mel - Epoch 820/1000
# Class mel - Epoch 830/1000
# Class mel - Epoch 840/1000
# Class mel - Epoch 850/1000
# Class mel - Epoch 860/1000
# Class mel - Epoch 870/1000
# Class mel - Epoch 880/1000
# Class mel - Epoch 890/1000
# Class mel - Epoch 900/1000
# Class mel - Epoch 910/1000
# Class mel - Epoch 920/1000
# Class mel - Epoch 930/1000
# Class mel - Epoch 940/1000
# Class mel - Epoch 950/1000
# Class mel - Epoch 960/1000
# Class mel - Epoch 970/1000
# Class mel - Epoch 980/1000
# Class mel - Epoch 990/1000
# Class mel - Epoch 1000/1000
# Saved 9 sample images for mel to C:\Users\abdur\vs_code\Sidra-Tasks\sidra thesis\Research Methadology Project-20250403T120511Z-0011\Research Methadology Project\Datasets\HAMM\GAN_generated_images\mel_samples
# Saved 2163 synthetic images for class mel to C:\Users\abdur\vs_code\Sidra-Tasks\sidra thesis\Research Methadology Project-20250403T120511Z-0011\Research Methadology Project\Datasets\HAMM\GAN_generated_images\mel_synthetic
# Memory cleared
# Class bkl: 481 original, generating 2303 synthetic images
# Training GAN for class bkl...
# Class bkl - Epoch 10/1000
# Class bkl - Epoch 20/1000
# Class bkl - Epoch 30/1000
# Class bkl - Epoch 40/1000
# Class bkl - Epoch 50/1000
# Class bkl - Epoch 60/1000
# Class bkl - Epoch 70/1000
# Class bkl - Epoch 80/1000
# Class bkl - Epoch 90/1000
# Class bkl - Epoch 100/1000
# Class bkl - Epoch 110/1000
# Class bkl - Epoch 120/1000
# Class bkl - Epoch 130/1000
# Class bkl - Epoch 140/1000
# Class bkl - Epoch 150/1000
# Class bkl - Epoch 160/1000
# Class bkl - Epoch 170/1000
# Class bkl - Epoch 180/1000
# Class bkl - Epoch 190/1000
# Class bkl - Epoch 200/1000
# Class bkl - Epoch 210/1000
# Class bkl - Epoch 220/1000
# Class bkl - Epoch 230/1000
# Class bkl - Epoch 240/1000
# Class bkl - Epoch 250/1000
# Class bkl - Epoch 260/1000
# Class bkl - Epoch 270/1000
# Class bkl - Epoch 280/1000
# Class bkl - Epoch 290/1000
# Class bkl - Epoch 300/1000
# Class bkl - Epoch 310/1000
# Class bkl - Epoch 320/1000
# Class bkl - Epoch 330/1000
# Class bkl - Epoch 340/1000
# Class bkl - Epoch 350/1000
# Class bkl - Epoch 360/1000
# Class bkl - Epoch 370/1000
# Class bkl - Epoch 380/1000
# Class bkl - Epoch 390/1000
# Class bkl - Epoch 400/1000
# Class bkl - Epoch 410/1000
# Class bkl - Epoch 420/1000
# Class bkl - Epoch 430/1000
# Class bkl - Epoch 440/1000
# Class bkl - Epoch 450/1000
# Class bkl - Epoch 460/1000
# Class bkl - Epoch 470/1000
# Class bkl - Epoch 480/1000
# Class bkl - Epoch 490/1000
# Class bkl - Epoch 500/1000
# Class bkl - Epoch 510/1000
# Class bkl - Epoch 520/1000
# Class bkl - Epoch 530/1000
# Class bkl - Epoch 540/1000
# Class bkl - Epoch 550/1000
# Class bkl - Epoch 560/1000
# Class bkl - Epoch 570/1000
# Class bkl - Epoch 580/1000
# Class bkl - Epoch 590/1000
# Class bkl - Epoch 600/1000
# Class bkl - Epoch 610/1000
# Class bkl - Epoch 620/1000
# Class bkl - Epoch 630/1000
# Class bkl - Epoch 640/1000
# Class bkl - Epoch 650/1000
# Class bkl - Epoch 660/1000
# Class bkl - Epoch 670/1000
# Class bkl - Epoch 680/1000
# Class bkl - Epoch 690/1000
# Class bkl - Epoch 700/1000
# Class bkl - Epoch 710/1000
# Class bkl - Epoch 720/1000
# Class bkl - Epoch 730/1000
# Class bkl - Epoch 740/1000
# Class bkl - Epoch 750/1000
# Class bkl - Epoch 760/1000
# Class bkl - Epoch 770/1000
# Class bkl - Epoch 780/1000
# Class bkl - Epoch 790/1000
# Class bkl - Epoch 800/1000
# Class bkl - Epoch 810/1000
# Class bkl - Epoch 820/1000
# Class bkl - Epoch 830/1000
# Class bkl - Epoch 840/1000
# Class bkl - Epoch 850/1000
# Class bkl - Epoch 860/1000
# Class bkl - Epoch 870/1000
# Class bkl - Epoch 880/1000
# Class bkl - Epoch 890/1000
# Class bkl - Epoch 900/1000
# Class bkl - Epoch 910/1000
# Class bkl - Epoch 920/1000
# Class bkl - Epoch 930/1000
# Class bkl - Epoch 940/1000
# Class bkl - Epoch 950/1000
# Class bkl - Epoch 960/1000
# Class bkl - Epoch 970/1000
# Class bkl - Epoch 980/1000
# Class bkl - Epoch 990/1000
# Class bkl - Epoch 1000/1000
# Saved 9 sample images for bkl to C:\Users\abdur\vs_code\Sidra-Tasks\sidra thesis\Research Methadology Project-20250403T120511Z-0011\Research Methadology Project\Datasets\HAMM\GAN_generated_images\bkl_samples
# Saved 2303 synthetic images for class bkl to C:\Users\abdur\vs_code\Sidra-Tasks\sidra thesis\Research Methadology Project-20250403T120511Z-0011\Research Methadology Project\Datasets\HAMM\GAN_generated_images\bkl_synthetic
# Memory cleared
# Class bcc: 214 original, generating 2570 synthetic images
# Training GAN for class bcc...
# Class bcc - Epoch 10/1000
# Class bcc - Epoch 20/1000
# Class bcc - Epoch 30/1000
# Class bcc - Epoch 40/1000
# Class bcc - Epoch 50/1000
# Class bcc - Epoch 60/1000
# Class bcc - Epoch 70/1000
# Class bcc - Epoch 80/1000
# Class bcc - Epoch 90/1000
# Class bcc - Epoch 100/1000
# Class bcc - Epoch 110/1000
# Class bcc - Epoch 120/1000
# Class bcc - Epoch 130/1000
# Class bcc - Epoch 140/1000
# Class bcc - Epoch 150/1000
# Class bcc - Epoch 160/1000
# Class bcc - Epoch 170/1000
# Class bcc - Epoch 180/1000
# Class bcc - Epoch 190/1000
# Class bcc - Epoch 200/1000
# Class bcc - Epoch 210/1000
# Class bcc - Epoch 220/1000
# Class bcc - Epoch 230/1000
# Class bcc - Epoch 240/1000
# Class bcc - Epoch 250/1000
# Class bcc - Epoch 260/1000
# Class bcc - Epoch 270/1000
# Class bcc - Epoch 280/1000
# Class bcc - Epoch 290/1000
# Class bcc - Epoch 300/1000
# Class bcc - Epoch 310/1000
# Class bcc - Epoch 320/1000
# Class bcc - Epoch 330/1000
# Class bcc - Epoch 340/1000
# Class bcc - Epoch 350/1000
# Class bcc - Epoch 360/1000
# Class bcc - Epoch 370/1000
# Class bcc - Epoch 380/1000
# Class bcc - Epoch 390/1000
# Class bcc - Epoch 400/1000
# Class bcc - Epoch 410/1000
# Class bcc - Epoch 420/1000
# Class bcc - Epoch 430/1000
# Class bcc - Epoch 440/1000
# Class bcc - Epoch 450/1000
# Class bcc - Epoch 460/1000
# Class bcc - Epoch 470/1000
# Class bcc - Epoch 480/1000
# Class bcc - Epoch 490/1000
# Class bcc - Epoch 500/1000
# Class bcc - Epoch 510/1000
# Class bcc - Epoch 520/1000
# Class bcc - Epoch 530/1000
# Class bcc - Epoch 540/1000
# Class bcc - Epoch 550/1000
# Class bcc - Epoch 560/1000
# Class bcc - Epoch 570/1000
# Class bcc - Epoch 580/1000
# Class bcc - Epoch 590/1000
# Class bcc - Epoch 600/1000
# Class bcc - Epoch 610/1000
# Class bcc - Epoch 620/1000
# Class bcc - Epoch 630/1000
# Class bcc - Epoch 640/1000
# Class bcc - Epoch 650/1000
# Class bcc - Epoch 660/1000
# Class bcc - Epoch 670/1000
# Class bcc - Epoch 680/1000
# Class bcc - Epoch 690/1000
# Class bcc - Epoch 700/1000
# Class bcc - Epoch 710/1000
# Class bcc - Epoch 720/1000
# Class bcc - Epoch 730/1000
# Class bcc - Epoch 740/1000
# Class bcc - Epoch 750/1000
# Class bcc - Epoch 760/1000
# Class bcc - Epoch 770/1000
# Class bcc - Epoch 780/1000
# Class bcc - Epoch 790/1000
# Class bcc - Epoch 800/1000
# Class bcc - Epoch 810/1000
# Class bcc - Epoch 820/1000
# Class bcc - Epoch 830/1000
# Class bcc - Epoch 840/1000
# Class bcc - Epoch 850/1000
# Class bcc - Epoch 860/1000
# Class bcc - Epoch 870/1000
# Class bcc - Epoch 880/1000
# Class bcc - Epoch 890/1000
# Class bcc - Epoch 900/1000
# Class bcc - Epoch 910/1000
# Class bcc - Epoch 920/1000
# Class bcc - Epoch 930/1000
# Class bcc - Epoch 940/1000
# Class bcc - Epoch 950/1000
# Class bcc - Epoch 960/1000
# Class bcc - Epoch 970/1000
# Class bcc - Epoch 980/1000
# Class bcc - Epoch 990/1000
# Class bcc - Epoch 1000/1000
# Saved 9 sample images for bcc to C:\Users\abdur\vs_code\Sidra-Tasks\sidra thesis\Research Methadology Project-20250403T120511Z-0011\Research Methadology Project\Datasets\HAMM\GAN_generated_images\bcc_samples
# Saved 2570 synthetic images for class bcc to C:\Users\abdur\vs_code\Sidra-Tasks\sidra thesis\Research Methadology Project-20250403T120511Z-0011\Research Methadology Project\Datasets\HAMM\GAN_generated_images\bcc_synthetic
# Memory cleared
# Class akiec: 109 original, generating 2675 synthetic images
# Training GAN for class akiec...
# Class akiec - Epoch 10/1000
# Class akiec - Epoch 20/1000
# Class akiec - Epoch 30/1000
# Class akiec - Epoch 40/1000
# Class akiec - Epoch 50/1000
# Class akiec - Epoch 60/1000
# Class akiec - Epoch 70/1000
# Class akiec - Epoch 80/1000
# Class akiec - Epoch 90/1000
# Class akiec - Epoch 100/1000
# Class akiec - Epoch 110/1000
# Class akiec - Epoch 120/1000
# Class akiec - Epoch 130/1000
# Class akiec - Epoch 140/1000
# Class akiec - Epoch 150/1000
# Class akiec - Epoch 160/1000
# Class akiec - Epoch 170/1000
# Class akiec - Epoch 180/1000
# Class akiec - Epoch 190/1000
# Class akiec - Epoch 200/1000
# Class akiec - Epoch 210/1000
# Class akiec - Epoch 220/1000
# Class akiec - Epoch 230/1000
# Class akiec - Epoch 240/1000
# Class akiec - Epoch 250/1000
# Class akiec - Epoch 260/1000
# Class akiec - Epoch 270/1000
# Class akiec - Epoch 280/1000
# Class akiec - Epoch 290/1000
# Class akiec - Epoch 300/1000
# Class akiec - Epoch 310/1000
# Class akiec - Epoch 320/1000
# Class akiec - Epoch 330/1000
# Class akiec - Epoch 340/1000
# Class akiec - Epoch 350/1000
# Class akiec - Epoch 360/1000
# Class akiec - Epoch 370/1000
# Class akiec - Epoch 380/1000
# Class akiec - Epoch 390/1000
# Class akiec - Epoch 400/1000
# Class akiec - Epoch 410/1000
# Class akiec - Epoch 420/1000
# Class akiec - Epoch 430/1000
# Class akiec - Epoch 440/1000
# Class akiec - Epoch 450/1000
# Class akiec - Epoch 460/1000
# Class akiec - Epoch 470/1000
# Class akiec - Epoch 480/1000
# Class akiec - Epoch 490/1000
# Class akiec - Epoch 500/1000
# Class akiec - Epoch 510/1000
# Class akiec - Epoch 520/1000
# Class akiec - Epoch 530/1000
# Class akiec - Epoch 540/1000
# Class akiec - Epoch 550/1000
# Class akiec - Epoch 560/1000
# Class akiec - Epoch 570/1000
# Class akiec - Epoch 580/1000
# Class akiec - Epoch 590/1000
# Class akiec - Epoch 600/1000
# Class akiec - Epoch 610/1000
# Class akiec - Epoch 620/1000
# Class akiec - Epoch 630/1000
# Class akiec - Epoch 640/1000
# Class akiec - Epoch 650/1000
# Class akiec - Epoch 660/1000
# Class akiec - Epoch 670/1000
# Class akiec - Epoch 680/1000
# Class akiec - Epoch 690/1000
# Class akiec - Epoch 700/1000
# Class akiec - Epoch 710/1000
# Class akiec - Epoch 720/1000
# Class akiec - Epoch 730/1000
# Class akiec - Epoch 740/1000
# Class akiec - Epoch 750/1000
# Class akiec - Epoch 760/1000
# Class akiec - Epoch 770/1000
# Class akiec - Epoch 780/1000
# Class akiec - Epoch 790/1000
# Class akiec - Epoch 800/1000
# Class akiec - Epoch 810/1000
# Class akiec - Epoch 820/1000
# Class akiec - Epoch 830/1000
# Class akiec - Epoch 840/1000
# Class akiec - Epoch 850/1000
# Class akiec - Epoch 860/1000
# Class akiec - Epoch 870/1000
# Class akiec - Epoch 880/1000
# Class akiec - Epoch 890/1000
# Class akiec - Epoch 900/1000
# Class akiec - Epoch 910/1000
# Class akiec - Epoch 920/1000
# Class akiec - Epoch 930/1000
# Class akiec - Epoch 940/1000
# Class akiec - Epoch 950/1000
# Class akiec - Epoch 960/1000
# Class akiec - Epoch 970/1000
# Class akiec - Epoch 980/1000
# Class akiec - Epoch 990/1000
# Class akiec - Epoch 1000/1000
# Saved 9 sample images for akiec to C:\Users\abdur\vs_code\Sidra-Tasks\sidra thesis\Research Methadology Project-20250403T120511Z-0011\Research Methadology Project\Datasets\HAMM\GAN_generated_images\akiec_samples
# Created directory: C:\Users\abdur\vs_code\Sidra-Tasks\sidra thesis\Research Methadology Project-20250403T120511Z-0011\Research Methadology Project\Datasets\HAMM\GAN_generated_images\akiec_synthetic
# Saved 2675 synthetic images for class akiec to C:\Users\abdur\vs_code\Sidra-Tasks\sidra thesis\Research Methadology Project-20250403T120511Z-0011\Research Methadology Project\Datasets\HAMM\GAN_generated_images\akiec_synthetic
# Memory cleared
# Class vasc: 64 original, generating 2720 synthetic images
# Training GAN for class vasc...
# Class vasc - Epoch 10/1000
# Class vasc - Epoch 20/1000
# Class vasc - Epoch 30/1000
# Class vasc - Epoch 40/1000
# Class vasc - Epoch 50/1000
# Class vasc - Epoch 60/1000
# Class vasc - Epoch 70/1000
# Class vasc - Epoch 80/1000
# Class vasc - Epoch 90/1000
# Class vasc - Epoch 100/1000
# Class vasc - Epoch 110/1000
# Class vasc - Epoch 120/1000
# Class vasc - Epoch 130/1000
# Class vasc - Epoch 140/1000
# Class vasc - Epoch 150/1000
# Class vasc - Epoch 160/1000
# Class vasc - Epoch 170/1000
# Class vasc - Epoch 180/1000
# Class vasc - Epoch 190/1000
# Class vasc - Epoch 200/1000
# Class vasc - Epoch 210/1000
# Class vasc - Epoch 220/1000
# Class vasc - Epoch 230/1000
# Class vasc - Epoch 240/1000
# Class vasc - Epoch 250/1000
# Class vasc - Epoch 260/1000
# Class vasc - Epoch 270/1000
# Class vasc - Epoch 280/1000
# Class vasc - Epoch 290/1000
# Class vasc - Epoch 300/1000
# Class vasc - Epoch 310/1000
# Class vasc - Epoch 320/1000
# Class vasc - Epoch 330/1000
# Class vasc - Epoch 340/1000
# Class vasc - Epoch 350/1000
# Class vasc - Epoch 360/1000
# Class vasc - Epoch 370/1000
# Class vasc - Epoch 380/1000
# Class vasc - Epoch 390/1000
# Class vasc - Epoch 400/1000
# Class vasc - Epoch 410/1000
# Class vasc - Epoch 420/1000
# Class vasc - Epoch 430/1000
# Class vasc - Epoch 440/1000
# Class vasc - Epoch 450/1000
# Class vasc - Epoch 460/1000
# Class vasc - Epoch 470/1000
# Class vasc - Epoch 480/1000
# Class vasc - Epoch 490/1000
# Class vasc - Epoch 500/1000
# Class vasc - Epoch 510/1000
# Class vasc - Epoch 520/1000
# Class vasc - Epoch 530/1000
# Class vasc - Epoch 540/1000
# Class vasc - Epoch 550/1000
# Class vasc - Epoch 560/1000
# Class vasc - Epoch 570/1000
# Class vasc - Epoch 580/1000
# Class vasc - Epoch 590/1000
# Class vasc - Epoch 600/1000
# Class vasc - Epoch 610/1000
# Class vasc - Epoch 620/1000
# Class vasc - Epoch 630/1000
# Class vasc - Epoch 640/1000
# Class vasc - Epoch 650/1000
# Class vasc - Epoch 660/1000
# Class vasc - Epoch 670/1000
# Class vasc - Epoch 680/1000
# Class vasc - Epoch 690/1000
# Class vasc - Epoch 700/1000
# Class vasc - Epoch 710/1000
# Class vasc - Epoch 720/1000
# Class vasc - Epoch 730/1000
# Class vasc - Epoch 740/1000
# Class vasc - Epoch 750/1000
# Class vasc - Epoch 760/1000
# Class vasc - Epoch 770/1000
# Class vasc - Epoch 780/1000
# Class vasc - Epoch 790/1000
# Class vasc - Epoch 800/1000
# Class vasc - Epoch 810/1000
# Class vasc - Epoch 820/1000
# Class vasc - Epoch 830/1000
# Class vasc - Epoch 840/1000
# Class vasc - Epoch 850/1000
# Class vasc - Epoch 860/1000
# Class vasc - Epoch 870/1000
# Class vasc - Epoch 880/1000
# Class vasc - Epoch 890/1000
# Class vasc - Epoch 900/1000
# Class vasc - Epoch 910/1000
# Class vasc - Epoch 920/1000
# Class vasc - Epoch 930/1000
# Class vasc - Epoch 940/1000
# Class vasc - Epoch 950/1000
# Class vasc - Epoch 960/1000
# Class vasc - Epoch 970/1000
# Class vasc - Epoch 980/1000
# Class vasc - Epoch 990/1000
# Class vasc - Epoch 1000/1000
# Saved 9 sample images for vasc to C:\Users\abdur\vs_code\Sidra-Tasks\sidra thesis\Research Methadology Project-20250403T120511Z-0011\Research Methadology Project\Datasets\HAMM\GAN_generated_images\vasc_samples
# Created directory: C:\Users\abdur\vs_code\Sidra-Tasks\sidra thesis\Research Methadology Project-20250403T120511Z-0011\Research Methadology Project\Datasets\HAMM\GAN_generated_images\vasc_synthetic
# Saved 2720 synthetic images for class vasc to C:\Users\abdur\vs_code\Sidra-Tasks\sidra thesis\Research Methadology Project-20250403T120511Z-0011\Research Methadology Project\Datasets\HAMM\GAN_generated_images\vasc_synthetic
# Memory cleared
# Class df: 52 original, generating 2732 synthetic images
# Training GAN for class df...
# Class df - Epoch 10/1000
# Class df - Epoch 20/1000
# Class df - Epoch 30/1000
# Class df - Epoch 40/1000
# Class df - Epoch 50/1000
# Class df - Epoch 60/1000
# Class df - Epoch 70/1000
# Class df - Epoch 80/1000
# Class df - Epoch 90/1000
# Class df - Epoch 100/1000
# Class df - Epoch 110/1000
# Class df - Epoch 120/1000
# Class df - Epoch 130/1000
# Class df - Epoch 140/1000
# Class df - Epoch 150/1000
# Class df - Epoch 160/1000
# Class df - Epoch 170/1000
# Class df - Epoch 180/1000
# Class df - Epoch 190/1000
# Class df - Epoch 200/1000
# Class df - Epoch 210/1000
# Class df - Epoch 220/1000
# Class df - Epoch 230/1000
# Class df - Epoch 240/1000
# Class df - Epoch 250/1000
# Class df - Epoch 260/1000
# Class df - Epoch 270/1000
# Class df - Epoch 280/1000
# Class df - Epoch 290/1000
# Class df - Epoch 300/1000
# Class df - Epoch 310/1000
# Class df - Epoch 320/1000
# Class df - Epoch 330/1000
# Class df - Epoch 340/1000
# Class df - Epoch 350/1000
# Class df - Epoch 360/1000
# Class df - Epoch 370/1000
# Class df - Epoch 380/1000
# Class df - Epoch 390/1000
# Class df - Epoch 400/1000
# Class df - Epoch 410/1000
# Class df - Epoch 420/1000
# Class df - Epoch 430/1000
# Class df - Epoch 440/1000
# Class df - Epoch 450/1000
# Class df - Epoch 460/1000
# Class df - Epoch 470/1000
# Class df - Epoch 480/1000
# Class df - Epoch 490/1000
# Class df - Epoch 500/1000
# Class df - Epoch 510/1000
# Class df - Epoch 520/1000
# Class df - Epoch 530/1000
# Class df - Epoch 540/1000
# Class df - Epoch 550/1000
# Class df - Epoch 560/1000
# Class df - Epoch 570/1000
# Class df - Epoch 580/1000
# Class df - Epoch 590/1000
# Class df - Epoch 600/1000
# Class df - Epoch 610/1000
# Class df - Epoch 620/1000
# Class df - Epoch 630/1000
# Class df - Epoch 640/1000
# Class df - Epoch 650/1000
# Class df - Epoch 660/1000
# Class df - Epoch 670/1000
# Class df - Epoch 680/1000
# Class df - Epoch 690/1000
# Class df - Epoch 700/1000
# Class df - Epoch 710/1000
# Class df - Epoch 720/1000
# Class df - Epoch 730/1000
# Class df - Epoch 740/1000
# Class df - Epoch 750/1000
# Class df - Epoch 760/1000
# Class df - Epoch 770/1000
# Class df - Epoch 780/1000
# Class df - Epoch 790/1000
# Class df - Epoch 800/1000
# Class df - Epoch 810/1000
# Class df - Epoch 820/1000
# Class df - Epoch 830/1000
# Class df - Epoch 840/1000
# Class df - Epoch 850/1000
# Class df - Epoch 860/1000
# Class df - Epoch 870/1000
# Class df - Epoch 880/1000
# Class df - Epoch 890/1000
# Class df - Epoch 900/1000
# Class df - Epoch 910/1000
# Class df - Epoch 920/1000
# Class df - Epoch 930/1000
# Class df - Epoch 940/1000
# Class df - Epoch 950/1000
# Class df - Epoch 960/1000
# Class df - Epoch 970/1000
# Class df - Epoch 980/1000
# Class df - Epoch 990/1000
# Class df - Epoch 1000/1000
# Saved 9 sample images for df to C:\Users\abdur\vs_code\Sidra-Tasks\sidra thesis\Research Methadology Project-20250403T120511Z-0011\Research Methadology Project\Datasets\HAMM\GAN_generated_images\df_samples
# Created directory: C:\Users\abdur\vs_code\Sidra-Tasks\sidra thesis\Research Methadology Project-20250403T120511Z-0011\Research Methadology Project\Datasets\HAMM\GAN_generated_images\df_synthetic
# Saved 2732 synthetic images for class df to C:\Users\abdur\vs_code\Sidra-Tasks\sidra thesis\Research Methadology Project-20250403T120511Z-0011\Research Methadology Project\Datasets\HAMM\GAN_generated_images\df_synthetic
# Memory cleared
#
# Final balanced dataset: 19488 images
#
# ============================================================
# DATA PREPARATION COMPLETE
# ============================================================
# Training set: 15590 samples
# Test set: 3898 samples
# Classes available: ['nv', 'mel', 'bkl', 'bcc', 'akiec', 'vasc', 'df']
# Variables created: balanced_data, train_data, test_data, config, create_custom_generator
# Ready for model training!

# %%
import time
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, BatchNormalization, MaxPool2D, GlobalAveragePooling2D, Dropout, Dense
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping
from tensorflow.keras.applications import ResNet50, ResNet101, EfficientNetB0
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import classification_report, confusion_matrix
import gc

EPOCHS = 100

def create_custom_cnn():
    model = Sequential([
        Conv2D(32, (3, 3), activation='relu', input_shape=(config.IMAGE_SIZE, config.IMAGE_SIZE, 3)),
        BatchNormalization(),
        MaxPool2D(2, 2),
        Conv2D(64, (3, 3), activation='relu'),
        BatchNormalization(),
        MaxPool2D(2, 2),
        Conv2D(128, (3, 3), activation='relu'),
        BatchNormalization(),
        MaxPool2D(2, 2),
        Conv2D(256, (3, 3), activation='relu'),
        BatchNormalization(),
        MaxPool2D(2, 2),
        GlobalAveragePooling2D(),
        Dropout(0.5),
        Dense(256, activation='relu'),
        Dropout(0.5),
        Dense(7, activation='softmax')
    ])
    return model

def create_resnet50():
    base_model = ResNet50(weights='imagenet', include_top=False, input_shape=(config.IMAGE_SIZE, config.IMAGE_SIZE, 3))
    for layer in base_model.layers[-10:]:
        layer.trainable = True
    model = Sequential([
        base_model,
        GlobalAveragePooling2D(),
        Dropout(0.5),
        Dense(256, activation='relu'),
        Dropout(0.5),
        Dense(7, activation='softmax')
    ])
    return model

def create_resnet101():
    base_model = ResNet101(weights='imagenet', include_top=False, input_shape=(config.IMAGE_SIZE, config.IMAGE_SIZE, 3))
    for layer in base_model.layers[-15:]:
        layer.trainable = True
    model = Sequential([
        base_model,
        GlobalAveragePooling2D(),
        Dropout(0.5),
        Dense(256, activation='relu'),
        Dropout(0.5),
        Dense(7, activation='softmax')
    ])
    return model

def create_efficientnet():
    base_model = EfficientNetB0(weights='imagenet', include_top=False, input_shape=(config.IMAGE_SIZE, config.IMAGE_SIZE, 3))
    for layer in base_model.layers[-20:]:
        layer.trainable = True
    model = Sequential([
        base_model,
        GlobalAveragePooling2D(),
        Dropout(0.5),
        Dense(256, activation='relu'),
        Dropout(0.5),
        Dense(7, activation='softmax')
    ])
    return model

def compile_model(model):
    model.compile(
        optimizer=Adam(learning_rate=0.001),
        loss='sparse_categorical_crossentropy',
        metrics=['accuracy']
    )
    return model

def train_and_evaluate_model(model, model_name, train_data, test_data):
    print(f"\n{'='*50}")
    print(f"Training {model_name}")
    print(f"{'='*50}")
    
    train_steps = len(train_data) // config.BATCH_SIZE
    val_steps = int(train_steps * config.VALIDATION_SPLIT)
    test_steps = len(test_data) // config.BATCH_SIZE
    
    train_generator = create_custom_generator(train_data, config.BATCH_SIZE)
    val_generator = create_custom_generator(train_data.sample(int(len(train_data) * config.VALIDATION_SPLIT)), config.BATCH_SIZE)
    test_generator = create_custom_generator(test_data, config.BATCH_SIZE)
    
    early_stopping = EarlyStopping(monitor='val_loss', patience=8, restore_best_weights=True, verbose=1)
    reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-7, verbose=1)
    
    start_time = time.time()
    history = model.fit(
        train_generator,
        steps_per_epoch=train_steps,
        epochs=EPOCHS,
        validation_data=val_generator,
        validation_steps=val_steps,
        callbacks=[early_stopping, reduce_lr],
        verbose=1
    )
    training_time = time.time() - start_time
    
    start_time = time.time()
    test_loss, test_accuracy = model.evaluate(test_generator, steps=test_steps, verbose=0)
    
    y_pred_list = []
    y_true_list = []
    for i, (batch_x, batch_y) in enumerate(test_generator):
        if i >= test_steps:
            break
        batch_pred = model.predict(batch_x, verbose=0)
        y_pred_list.extend(np.argmax(batch_pred, axis=1))
        y_true_list.extend(batch_y)
    
    y_pred = np.array(y_pred_list)
    y_test = np.array(y_true_list)
    testing_time = time.time() - start_time
    
    cm = confusion_matrix(y_test, y_pred)
    cm_percentage = (cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]) * 100
    
    print(f"\nTraining Time: {training_time:.2f} seconds")
    print(f"Testing Time: {testing_time:.2f} seconds")
    print(f"Test Accuracy: {test_accuracy:.3f}")
    
    print(f"\nConfusion Matrix (Percentage) for {model_name}:")
    print(cm_percentage)
    
    report = classification_report(y_test, y_pred, digits=3)
    print(f"\nClassification Report for {model_name}:")
    print(report)
    
    plt.figure(figsize=(15, 5))
    
    plt.subplot(1, 3, 1)
    epochs_range = range(1, len(history.history['loss']) + 1)
    plt.plot(epochs_range, history.history['loss'], 'bo-', label='Training Loss')
    plt.plot(epochs_range, history.history['val_loss'], 'ro-', label='Validation Loss')
    plt.title(f'{model_name} - Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True)
    
    plt.subplot(1, 3, 2)
    plt.plot(epochs_range, history.history['accuracy'], 'bo-', label='Training Accuracy')
    plt.plot(epochs_range, history.history['val_accuracy'], 'ro-', label='Validation Accuracy')
    plt.title(f'{model_name} - Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.grid(True)
    
    plt.subplot(1, 3, 3)
    sns.heatmap(cm_percentage, annot=True, fmt='.1f', cmap='Blues')
    plt.title(f'{model_name} - Confusion Matrix (%)')
    plt.ylabel('True Label')
    plt.xlabel('Predicted Label')
    
    plt.tight_layout()
    plt.show()
    
    del model
    tf.keras.backend.clear_session()
    gc.collect()
    
    return history, training_time, testing_time, test_accuracy

models_config = [
    (create_custom_cnn, "Custom CNN"),
    (create_resnet50, "ResNet50"),
    (create_resnet101, "ResNet101"),
    (create_efficientnet, "EfficientNet-B0")
]

results = {}

for model_func, model_name in models_config:
    model = compile_model(model_func())
    history, train_time, test_time, test_acc = train_and_evaluate_model(
        model, model_name, train_data, test_data
    )
    results[model_name] = {
        'history': history,
        'train_time': train_time,
        'test_time': test_time,
        'test_accuracy': test_acc
    }

print(f"\n{'='*60}")
print("SUMMARY OF ALL MODELS")
print(f"{'='*60}")
for name, result in results.items():
    print(f"{name:15} | Accuracy: {result['test_accuracy']:.3f} | Train Time: {result['train_time']:.2f}s | Test Time: {result['test_time']:.2f}s")
# Out:
# ==================================================
# Training Custom CNN
# ==================================================
# Epoch 1/100
# 974/974 [==============================] - 48s 49ms/step - loss: 0.9563 - accuracy: 0.6823 - val_loss: 5.8954 - val_accuracy: 0.2452 - lr: 0.0010
# Epoch 2/100
# 974/974 [==============================] - 46s 47ms/step - loss: 0.5161 - accuracy: 0.8302 - val_loss: 0.8788 - val_accuracy: 0.6936 - lr: 0.0010
# Epoch 3/100
# 974/974 [==============================] - 47s 48ms/step - loss: 0.3327 - accuracy: 0.8872 - val_loss: 0.6438 - val_accuracy: 0.7680 - lr: 0.0010
# Epoch 4/100
# 974/974 [==============================] - 47s 48ms/step - loss: 0.2712 - accuracy: 0.9055 - val_loss: 0.3973 - val_accuracy: 0.8595 - lr: 0.0010
# Epoch 5/100
# 974/974 [==============================] - 47s 48ms/step - loss: 0.2490 - accuracy: 0.9140 - val_loss: 0.7880 - val_accuracy: 0.6885 - lr: 0.0010
# Epoch 6/100
# 974/974 [==============================] - 47s 48ms/step - loss: 0.2310 - accuracy: 0.9163 - val_loss: 0.6682 - val_accuracy: 0.7494 - lr: 0.0010
# Epoch 7/100
# 974/974 [==============================] - 48s 49ms/step - loss: 0.2344 - accuracy: 0.9151 - val_loss: 1.6215 - val_accuracy: 0.3515 - lr: 0.0010
# Epoch 8/100
# 974/974 [==============================] - 47s 48ms/step - loss: 0.2319 - accuracy: 0.9169 - val_loss: 3.3469 - val_accuracy: 0.2155 - lr: 0.0010
# Epoch 9/100
# 974/974 [==============================] - ETA: 0s - loss: 0.2107 - accuracy: 0.9235
# Epoch 9: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 974/974 [==============================] - 48s 49ms/step - loss: 0.2107 - accuracy: 0.9235 - val_loss: 4.0753 - val_accuracy: 0.5348 - lr: 0.0010
# Epoch 10/100
# 974/974 [==============================] - 48s 49ms/step - loss: 0.1857 - accuracy: 0.9305 - val_loss: 0.1637 - val_accuracy: 0.9372 - lr: 5.0000e-04
# Epoch 11/100
# 974/974 [==============================] - 47s 49ms/step - loss: 0.1861 - accuracy: 0.9324 - val_loss: 0.2183 - val_accuracy: 0.9214 - lr: 5.0000e-04
# Epoch 12/100
# 974/974 [==============================] - 47s 49ms/step - loss: 0.1781 - accuracy: 0.9330 - val_loss: 0.3465 - val_accuracy: 0.8708 - lr: 5.0000e-04
# Epoch 13/100
# 974/974 [==============================] - 47s 48ms/step - loss: 0.1735 - accuracy: 0.9350 - val_loss: 1.4163 - val_accuracy: 0.5135 - lr: 5.0000e-04
# Epoch 14/100
# 974/974 [==============================] - 48s 49ms/step - loss: 0.1727 - accuracy: 0.9340 - val_loss: 0.2079 - val_accuracy: 0.9330 - lr: 5.0000e-04
# Epoch 15/100
# 974/974 [==============================] - 48s 50ms/step - loss: 0.1633 - accuracy: 0.9383 - val_loss: 0.1396 - val_accuracy: 0.9430 - lr: 5.0000e-04
# Epoch 16/100
# 974/974 [==============================] - 48s 50ms/step - loss: 0.1619 - accuracy: 0.9395 - val_loss: 2.1937 - val_accuracy: 0.7055 - lr: 5.0000e-04
# Epoch 17/100
# 974/974 [==============================] - 49s 50ms/step - loss: 0.1635 - accuracy: 0.9389 - val_loss: 0.2319 - val_accuracy: 0.9153 - lr: 5.0000e-04
# Epoch 18/100
# 974/974 [==============================] - 48s 49ms/step - loss: 0.1586 - accuracy: 0.9413 - val_loss: 0.2087 - val_accuracy: 0.9240 - lr: 5.0000e-04
# Epoch 19/100
# 974/974 [==============================] - 48s 49ms/step - loss: 0.1519 - accuracy: 0.9421 - val_loss: 0.2029 - val_accuracy: 0.9294 - lr: 5.0000e-04
# Epoch 20/100
# 974/974 [==============================] - ETA: 0s - loss: 0.1568 - accuracy: 0.9413
# Epoch 20: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 974/974 [==============================] - 48s 50ms/step - loss: 0.1568 - accuracy: 0.9413 - val_loss: 0.2092 - val_accuracy: 0.9243 - lr: 5.0000e-04
# Epoch 21/100
# 974/974 [==============================] - 48s 49ms/step - loss: 0.1394 - accuracy: 0.9484 - val_loss: 0.1634 - val_accuracy: 0.9446 - lr: 2.5000e-04
# Epoch 22/100
# 974/974 [==============================] - 48s 49ms/step - loss: 0.1347 - accuracy: 0.9488 - val_loss: 0.2180 - val_accuracy: 0.9330 - lr: 2.5000e-04
# Epoch 23/100
# 974/974 [==============================] - ETA: 0s - loss: 0.1308 - accuracy: 0.9511Restoring model weights from the end of the best epoch: 15.
# 974/974 [==============================] - 48s 49ms/step - loss: 0.1308 - accuracy: 0.9511 - val_loss: 0.1613 - val_accuracy: 0.9385 - lr: 2.5000e-04
# Epoch 23: early stopping
#
# Training Time: 1095.27 seconds
# Testing Time: 28.69 seconds
# Test Accuracy: 0.946
#
# Confusion Matrix (Percentage) for Custom CNN:
# [[92.8057554   1.97841727  2.87769784  2.15827338  0.          0.17985612
#    0.        ]
#  [ 9.38628159 88.44765343  1.80505415  0.36101083  0.          0.
#    0.        ]
#  [ 8.10810811  1.62162162 89.18918919  0.9009009   0.          0.
#    0.18018018]
#  [ 1.43626571  0.35906643  0.53859964 97.48653501  0.17953321  0.
#    0.        ]
#  [ 1.43884892  0.35971223  0.53956835  0.71942446 96.94244604  0.
#    0.        ]
#  [ 0.54054054  0.          0.          0.          0.         99.45945946
#    0.        ]
#  [ 1.26126126  0.          0.36036036  0.54054054  0.          0.
#   97.83783784]]
#
# Classification Report for Custom CNN:
#               precision    recall  f1-score   support
#
#            0      0.808     0.928     0.864       556
#            1      0.953     0.884     0.918       554
#            2      0.936     0.892     0.913       555
#            3      0.954     0.975     0.964       557
#            4      0.998     0.969     0.984       556
#            5      0.998     0.995     0.996       555
#            6      0.998     0.978     0.988       555
#
#     accuracy                          0.946      3888
#    macro avg      0.949     0.946     0.947      3888
# weighted avg      0.949     0.946     0.947      3888
# ==================================================
# Training ResNet50
# ==================================================
# Epoch 1/100
# 974/974 [==============================] - 133s 133ms/step - loss: 0.4784 - accuracy: 0.8544 - val_loss: 0.4547 - val_accuracy: 0.8692 - lr: 0.0010
# Epoch 2/100
# 974/974 [==============================] - 128s 131ms/step - loss: 0.2483 - accuracy: 0.9124 - val_loss: 0.2453 - val_accuracy: 0.9111 - lr: 0.0010
# Epoch 3/100
# 974/974 [==============================] - 128s 131ms/step - loss: 0.2427 - accuracy: 0.9149 - val_loss: 0.2024 - val_accuracy: 0.9275 - lr: 0.0010
# Epoch 4/100
# 974/974 [==============================] - 129s 132ms/step - loss: 0.2244 - accuracy: 0.9209 - val_loss: 0.8344 - val_accuracy: 0.7581 - lr: 0.0010
# Epoch 5/100
# 974/974 [==============================] - 127s 130ms/step - loss: 0.2227 - accuracy: 0.9212 - val_loss: 0.2764 - val_accuracy: 0.9001 - lr: 0.0010
# Epoch 6/100
# 974/974 [==============================] - 127s 131ms/step - loss: 0.1986 - accuracy: 0.9273 - val_loss: 0.3892 - val_accuracy: 0.8715 - lr: 0.0010
# Epoch 7/100
# 974/974 [==============================] - 127s 130ms/step - loss: 0.2221 - accuracy: 0.9217 - val_loss: 0.2901 - val_accuracy: 0.9072 - lr: 0.0010
# Epoch 8/100
# 974/974 [==============================] - 127s 130ms/step - loss: 0.1816 - accuracy: 0.9327 - val_loss: 0.1804 - val_accuracy: 0.9369 - lr: 0.0010
# Epoch 9/100
# 974/974 [==============================] - 127s 130ms/step - loss: 0.1785 - accuracy: 0.9344 - val_loss: 0.4144 - val_accuracy: 0.8486 - lr: 0.0010
# Epoch 10/100
# 974/974 [==============================] - 128s 131ms/step - loss: 0.1959 - accuracy: 0.9318 - val_loss: 2.2959 - val_accuracy: 0.4716 - lr: 0.0010
# Epoch 11/100
# 974/974 [==============================] - 127s 130ms/step - loss: 0.1852 - accuracy: 0.9341 - val_loss: 0.1684 - val_accuracy: 0.9407 - lr: 0.0010
# Epoch 12/100
# 974/974 [==============================] - 127s 130ms/step - loss: 0.1571 - accuracy: 0.9414 - val_loss: 0.1361 - val_accuracy: 0.9475 - lr: 0.0010
# Epoch 13/100
# 974/974 [==============================] - 127s 130ms/step - loss: 0.1456 - accuracy: 0.9461 - val_loss: 1.3135 - val_accuracy: 0.5399 - lr: 0.0010
# Epoch 14/100
# 974/974 [==============================] - 127s 131ms/step - loss: 0.1700 - accuracy: 0.9443 - val_loss: 0.4119 - val_accuracy: 0.8673 - lr: 0.0010
# Epoch 15/100
# 974/974 [==============================] - 128s 131ms/step - loss: 0.1353 - accuracy: 0.9504 - val_loss: 0.1280 - val_accuracy: 0.9510 - lr: 0.0010
# Epoch 16/100
# 974/974 [==============================] - 127s 130ms/step - loss: 0.1122 - accuracy: 0.9589 - val_loss: 0.1370 - val_accuracy: 0.9520 - lr: 0.0010
# Epoch 17/100
# 974/974 [==============================] - 127s 130ms/step - loss: 0.1335 - accuracy: 0.9549 - val_loss: 0.1000 - val_accuracy: 0.9655 - lr: 0.0010
# Epoch 18/100
# 974/974 [==============================] - 127s 130ms/step - loss: 0.0969 - accuracy: 0.9649 - val_loss: 0.4061 - val_accuracy: 0.8814 - lr: 0.0010
# Epoch 19/100
# 974/974 [==============================] - 127s 130ms/step - loss: 0.0849 - accuracy: 0.9704 - val_loss: 0.1727 - val_accuracy: 0.9452 - lr: 0.0010
# Epoch 20/100
# 974/974 [==============================] - 127s 131ms/step - loss: 0.1018 - accuracy: 0.9660 - val_loss: 0.0581 - val_accuracy: 0.9820 - lr: 0.0010
# Epoch 21/100
# 974/974 [==============================] - 127s 130ms/step - loss: 0.0595 - accuracy: 0.9791 - val_loss: 0.0980 - val_accuracy: 0.9655 - lr: 0.0010
# Epoch 22/100
# 974/974 [==============================] - 127s 131ms/step - loss: 0.0541 - accuracy: 0.9814 - val_loss: 0.0735 - val_accuracy: 0.9762 - lr: 0.0010
# Epoch 23/100
# 974/974 [==============================] - 128s 131ms/step - loss: 0.0568 - accuracy: 0.9824 - val_loss: 0.3145 - val_accuracy: 0.9172 - lr: 0.0010
# Epoch 24/100
# 974/974 [==============================] - 128s 131ms/step - loss: 0.0583 - accuracy: 0.9832 - val_loss: 0.1838 - val_accuracy: 0.9423 - lr: 0.0010
# Epoch 25/100
# 974/974 [==============================] - ETA: 0s - loss: 0.0644 - accuracy: 0.9785
# Epoch 25: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 974/974 [==============================] - 127s 131ms/step - loss: 0.0644 - accuracy: 0.9785 - val_loss: 0.1399 - val_accuracy: 0.9507 - lr: 0.0010
# Epoch 26/100
# 974/974 [==============================] - 127s 131ms/step - loss: 0.0234 - accuracy: 0.9929 - val_loss: 0.0071 - val_accuracy: 0.9981 - lr: 5.0000e-04
# Epoch 27/100
# 974/974 [==============================] - 131s 134ms/step - loss: 0.0104 - accuracy: 0.9967 - val_loss: 0.0030 - val_accuracy: 0.9990 - lr: 5.0000e-04
# Epoch 28/100
# 974/974 [==============================] - 127s 130ms/step - loss: 0.0094 - accuracy: 0.9972 - val_loss: 0.1261 - val_accuracy: 0.9688 - lr: 5.0000e-04
# Epoch 29/100
# 974/974 [==============================] - 127s 130ms/step - loss: 0.0136 - accuracy: 0.9958 - val_loss: 0.0113 - val_accuracy: 0.9958 - lr: 5.0000e-04
# Epoch 30/100
# 974/974 [==============================] - 127s 131ms/step - loss: 0.0157 - accuracy: 0.9951 - val_loss: 0.0271 - val_accuracy: 0.9919 - lr: 5.0000e-04
# Epoch 31/100
# 974/974 [==============================] - 127s 130ms/step - loss: 0.0095 - accuracy: 0.9969 - val_loss: 0.0244 - val_accuracy: 0.9919 - lr: 5.0000e-04
# Epoch 32/100
# 974/974 [==============================] - ETA: 0s - loss: 0.0091 - accuracy: 0.9973
# Epoch 32: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 974/974 [==============================] - 127s 130ms/step - loss: 0.0091 - accuracy: 0.9973 - val_loss: 0.6344 - val_accuracy: 0.9066 - lr: 5.0000e-04
# Epoch 33/100
# 974/974 [==============================] - 127s 130ms/step - loss: 0.0058 - accuracy: 0.9981 - val_loss: 0.0018 - val_accuracy: 0.9997 - lr: 2.5000e-04
# Epoch 34/100
# 974/974 [==============================] - 127s 130ms/step - loss: 0.0042 - accuracy: 0.9987 - val_loss: 0.0013 - val_accuracy: 0.9994 - lr: 2.5000e-04
# Epoch 35/100
# 974/974 [==============================] - 127s 130ms/step - loss: 0.0043 - accuracy: 0.9989 - val_loss: 0.0015 - val_accuracy: 0.9997 - lr: 2.5000e-04
# Epoch 36/100
# 974/974 [==============================] - 127s 130ms/step - loss: 0.0044 - accuracy: 0.9987 - val_loss: 8.7197e-04 - val_accuracy: 0.9997 - lr: 2.5000e-04
# Epoch 37/100
# 974/974 [==============================] - 127s 130ms/step - loss: 0.0022 - accuracy: 0.9994 - val_loss: 1.2684e-04 - val_accuracy: 1.0000 - lr: 2.5000e-04
# Epoch 38/100
# 974/974 [==============================] - 127s 130ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.2585 - val_accuracy: 0.9394 - lr: 2.5000e-04
# Epoch 39/100
# 974/974 [==============================] - 127s 130ms/step - loss: 0.0032 - accuracy: 0.9990 - val_loss: 0.0072 - val_accuracy: 0.9977 - lr: 2.5000e-04
# Epoch 40/100
# 974/974 [==============================] - 126s 130ms/step - loss: 0.0048 - accuracy: 0.9987 - val_loss: 0.0036 - val_accuracy: 0.9994 - lr: 2.5000e-04
# Epoch 41/100
# 974/974 [==============================] - 127s 130ms/step - loss: 6.4522e-04 - accuracy: 0.9999 - val_loss: 1.6743e-04 - val_accuracy: 1.0000 - lr: 2.5000e-04
# Epoch 42/100
# 974/974 [==============================] - ETA: 0s - loss: 0.0041 - accuracy: 0.9985
# Epoch 42: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 974/974 [==============================] - 126s 130ms/step - loss: 0.0041 - accuracy: 0.9985 - val_loss: 0.0011 - val_accuracy: 0.9997 - lr: 2.5000e-04
# Epoch 43/100
# 974/974 [==============================] - 127s 130ms/step - loss: 0.0015 - accuracy: 0.9997 - val_loss: 0.0014 - val_accuracy: 0.9997 - lr: 1.2500e-04
# Epoch 44/100
# 974/974 [==============================] - 127s 130ms/step - loss: 0.0016 - accuracy: 0.9997 - val_loss: 2.0922e-04 - val_accuracy: 1.0000 - lr: 1.2500e-04
# Epoch 45/100
# 974/974 [==============================] - ETA: 0s - loss: 9.6372e-04 - accuracy: 0.9998Restoring model weights from the end of the best epoch: 37.
# 974/974 [==============================] - 127s 130ms/step - loss: 9.6372e-04 - accuracy: 0.9998 - val_loss: 5.1075e-04 - val_accuracy: 0.9997 - lr: 1.2500e-04
# Epoch 45: early stopping
#
# Training Time: 5727.26 seconds
# Testing Time: 38.92 seconds
# Test Accuracy: 0.937
#
# Confusion Matrix (Percentage) for ResNet50:
# [[90.09009009  5.40540541  2.88288288  1.08108108  0.18018018  0.18018018
#    0.18018018]
#  [ 8.28828829 88.46846847  2.7027027   0.54054054  0.          0.
#    0.        ]
#  [ 7.37410072  1.97841727 89.20863309  0.89928058  0.35971223  0.
#    0.17985612]
#  [ 2.16216216  0.9009009   1.08108108 95.13513514  0.36036036  0.18018018
#    0.18018018]
#  [ 0.71813285  0.35906643  1.61579892  0.35906643 96.76840215  0.
#    0.17953321]
#  [ 0.71813285  0.71813285  0.17953321  0.          0.         98.38420108
#    0.        ]
#  [ 0.90415913  0.          0.18083183  0.36166365  0.36166365  0.
#   98.19168174]]
#
# Classification Report for ResNet50:
#               precision    recall  f1-score   support
#
#            0      0.817     0.901     0.857       555
#            1      0.904     0.885     0.894       555
#            2      0.912     0.892     0.902       556
#            3      0.967     0.951     0.959       555
#            4      0.987     0.968     0.977       557
#            5      0.996     0.984     0.990       557
#            6      0.993     0.982     0.987       553
#
#     accuracy                          0.938      3888
#    macro avg      0.939     0.937     0.938      3888
# weighted avg      0.939     0.938     0.938      3888
# ==================================================
# Training ResNet101
# ==================================================
# Epoch 1/100
# 974/974 [==============================] - 196s 193ms/step - loss: 0.5552 - accuracy: 0.8327 - val_loss: 28.5403 - val_accuracy: 0.1411 - lr: 0.0010
# Epoch 2/100
# 974/974 [==============================] - 186s 191ms/step - loss: 0.3175 - accuracy: 0.8973 - val_loss: 0.5083 - val_accuracy: 0.8386 - lr: 0.0010
# Epoch 3/100
# 974/974 [==============================] - 186s 190ms/step - loss: 0.2554 - accuracy: 0.9098 - val_loss: 1.4656 - val_accuracy: 0.5625 - lr: 0.0010
# Epoch 4/100
# 974/974 [==============================] - 186s 191ms/step - loss: 0.2356 - accuracy: 0.9147 - val_loss: 1.8511 - val_accuracy: 0.2748 - lr: 0.0010
# Epoch 5/100
# 974/974 [==============================] - 186s 191ms/step - loss: 0.2816 - accuracy: 0.9058 - val_loss: 0.2994 - val_accuracy: 0.9079 - lr: 0.0010
# Epoch 6/100
# 974/974 [==============================] - 186s 191ms/step - loss: 0.2259 - accuracy: 0.9199 - val_loss: 0.9836 - val_accuracy: 0.6247 - lr: 0.0010
# Epoch 7/100
# 974/974 [==============================] - 186s 191ms/step - loss: 0.2196 - accuracy: 0.9201 - val_loss: 1.3752 - val_accuracy: 0.6186 - lr: 0.0010
# Epoch 8/100
# 974/974 [==============================] - 186s 191ms/step - loss: 0.2230 - accuracy: 0.9187 - val_loss: 1.0906 - val_accuracy: 0.6160 - lr: 0.0010
# Epoch 9/100
# 974/974 [==============================] - 186s 191ms/step - loss: 0.2290 - accuracy: 0.9192 - val_loss: 0.2002 - val_accuracy: 0.9246 - lr: 0.0010
# Epoch 10/100
# 974/974 [==============================] - 186s 191ms/step - loss: 0.1917 - accuracy: 0.9290 - val_loss: 0.2642 - val_accuracy: 0.9175 - lr: 0.0010
# Epoch 11/100
# 974/974 [==============================] - 186s 191ms/step - loss: 0.1899 - accuracy: 0.9304 - val_loss: 0.4032 - val_accuracy: 0.8840 - lr: 0.0010
# Epoch 12/100
# 974/974 [==============================] - 186s 191ms/step - loss: 0.1832 - accuracy: 0.9302 - val_loss: 0.6531 - val_accuracy: 0.7758 - lr: 0.0010
# Epoch 13/100
# 974/974 [==============================] - 186s 191ms/step - loss: 0.2049 - accuracy: 0.9296 - val_loss: 0.6004 - val_accuracy: 0.7899 - lr: 0.0010
# Epoch 14/100
# 974/974 [==============================] - 186s 191ms/step - loss: 0.1831 - accuracy: 0.9314 - val_loss: 0.1521 - val_accuracy: 0.9372 - lr: 0.0010
# Epoch 15/100
# 974/974 [==============================] - 186s 191ms/step - loss: 0.1838 - accuracy: 0.9360 - val_loss: 0.1509 - val_accuracy: 0.9401 - lr: 0.0010
# Epoch 16/100
# 974/974 [==============================] - 186s 191ms/step - loss: 0.1529 - accuracy: 0.9429 - val_loss: 0.1645 - val_accuracy: 0.9401 - lr: 0.0010
# Epoch 17/100
# 974/974 [==============================] - 186s 191ms/step - loss: 0.1436 - accuracy: 0.9457 - val_loss: 0.1550 - val_accuracy: 0.9410 - lr: 0.0010
# Epoch 18/100
# 974/974 [==============================] - 186s 191ms/step - loss: 0.1517 - accuracy: 0.9473 - val_loss: 0.2824 - val_accuracy: 0.9053 - lr: 0.0010
# Epoch 19/100
# 974/974 [==============================] - 186s 191ms/step - loss: 0.1371 - accuracy: 0.9503 - val_loss: 0.2733 - val_accuracy: 0.9072 - lr: 0.0010
# Epoch 20/100
# 974/974 [==============================] - ETA: 0s - loss: 0.1204 - accuracy: 0.9570
# Epoch 20: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 974/974 [==============================] - 186s 191ms/step - loss: 0.1204 - accuracy: 0.9570 - val_loss: 0.1703 - val_accuracy: 0.9391 - lr: 0.0010
# Epoch 21/100
# 974/974 [==============================] - 186s 191ms/step - loss: 0.0762 - accuracy: 0.9730 - val_loss: 0.0429 - val_accuracy: 0.9874 - lr: 5.0000e-04
# Epoch 22/100
# 974/974 [==============================] - 186s 191ms/step - loss: 0.0522 - accuracy: 0.9821 - val_loss: 0.0439 - val_accuracy: 0.9849 - lr: 5.0000e-04
# Epoch 23/100
# 974/974 [==============================] - 186s 191ms/step - loss: 0.0465 - accuracy: 0.9844 - val_loss: 0.1275 - val_accuracy: 0.9523 - lr: 5.0000e-04
# Epoch 24/100
# 974/974 [==============================] - 186s 191ms/step - loss: 0.0313 - accuracy: 0.9897 - val_loss: 0.0512 - val_accuracy: 0.9829 - lr: 5.0000e-04
# Epoch 25/100
# 974/974 [==============================] - 186s 191ms/step - loss: 0.0343 - accuracy: 0.9891 - val_loss: 0.1426 - val_accuracy: 0.9562 - lr: 5.0000e-04
# Epoch 26/100
# 974/974 [==============================] - ETA: 0s - loss: 0.0348 - accuracy: 0.9890
# Epoch 26: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 974/974 [==============================] - 186s 191ms/step - loss: 0.0348 - accuracy: 0.9890 - val_loss: 0.0630 - val_accuracy: 0.9794 - lr: 5.0000e-04
# Epoch 27/100
# 974/974 [==============================] - 187s 192ms/step - loss: 0.0144 - accuracy: 0.9956 - val_loss: 0.0032 - val_accuracy: 0.9994 - lr: 2.5000e-04
# Epoch 28/100
# 974/974 [==============================] - 187s 191ms/step - loss: 0.0132 - accuracy: 0.9967 - val_loss: 0.0019 - val_accuracy: 1.0000 - lr: 2.5000e-04
# Epoch 29/100
# 974/974 [==============================] - 185s 190ms/step - loss: 0.0101 - accuracy: 0.9969 - val_loss: 0.0060 - val_accuracy: 0.9984 - lr: 2.5000e-04
# Epoch 30/100
# 974/974 [==============================] - 185s 190ms/step - loss: 0.0069 - accuracy: 0.9978 - val_loss: 0.0032 - val_accuracy: 0.9994 - lr: 2.5000e-04
# Epoch 31/100
# 974/974 [==============================] - 185s 190ms/step - loss: 0.0069 - accuracy: 0.9977 - val_loss: 0.0016 - val_accuracy: 0.9997 - lr: 2.5000e-04
# Epoch 32/100
# 974/974 [==============================] - 186s 191ms/step - loss: 0.0060 - accuracy: 0.9980 - val_loss: 9.8685e-04 - val_accuracy: 0.9997 - lr: 2.5000e-04
# Epoch 33/100
# 974/974 [==============================] - 185s 190ms/step - loss: 0.0082 - accuracy: 0.9971 - val_loss: 0.0094 - val_accuracy: 0.9965 - lr: 2.5000e-04
# Epoch 34/100
# 974/974 [==============================] - 186s 191ms/step - loss: 0.0061 - accuracy: 0.9979 - val_loss: 6.1367e-04 - val_accuracy: 1.0000 - lr: 2.5000e-04
# Epoch 35/100
# 974/974 [==============================] - 186s 191ms/step - loss: 0.0038 - accuracy: 0.9988 - val_loss: 0.0014 - val_accuracy: 0.9997 - lr: 2.5000e-04
# Epoch 36/100
# 974/974 [==============================] - 185s 190ms/step - loss: 0.0067 - accuracy: 0.9982 - val_loss: 0.0403 - val_accuracy: 0.9881 - lr: 2.5000e-04
# Epoch 37/100
# 974/974 [==============================] - 186s 191ms/step - loss: 0.0063 - accuracy: 0.9980 - val_loss: 3.6840e-04 - val_accuracy: 1.0000 - lr: 2.5000e-04
# Epoch 38/100
# 974/974 [==============================] - 186s 191ms/step - loss: 0.0040 - accuracy: 0.9988 - val_loss: 5.2506e-04 - val_accuracy: 1.0000 - lr: 2.5000e-04
# Epoch 39/100
# 974/974 [==============================] - 186s 191ms/step - loss: 0.0052 - accuracy: 0.9985 - val_loss: 2.9667e-04 - val_accuracy: 1.0000 - lr: 2.5000e-04
# Epoch 40/100
# 974/974 [==============================] - 185s 190ms/step - loss: 0.0042 - accuracy: 0.9987 - val_loss: 0.0052 - val_accuracy: 0.9987 - lr: 2.5000e-04
# Epoch 41/100
# 974/974 [==============================] - 186s 191ms/step - loss: 0.0062 - accuracy: 0.9981 - val_loss: 5.8172e-04 - val_accuracy: 1.0000 - lr: 2.5000e-04
# Epoch 42/100
# 974/974 [==============================] - ETA: 0s - loss: 0.0046 - accuracy: 0.9984
# Epoch 42: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 974/974 [==============================] - 186s 191ms/step - loss: 0.0046 - accuracy: 0.9984 - val_loss: 0.0070 - val_accuracy: 0.9977 - lr: 2.5000e-04
# Epoch 43/100
# 974/974 [==============================] - 186s 191ms/step - loss: 0.0034 - accuracy: 0.9992 - val_loss: 7.9278e-05 - val_accuracy: 1.0000 - lr: 1.2500e-04
# Epoch 44/100
# 974/974 [==============================] - 186s 191ms/step - loss: 0.0015 - accuracy: 0.9998 - val_loss: 3.6612e-05 - val_accuracy: 1.0000 - lr: 1.2500e-04
# Epoch 45/100
# 974/974 [==============================] - 186s 191ms/step - loss: 7.0384e-04 - accuracy: 0.9998 - val_loss: 2.6282e-05 - val_accuracy: 1.0000 - lr: 1.2500e-04
# Epoch 46/100
# 974/974 [==============================] - 185s 190ms/step - loss: 0.0019 - accuracy: 0.9994 - val_loss: 3.6796e-04 - val_accuracy: 1.0000 - lr: 1.2500e-04
# Epoch 47/100
# 974/974 [==============================] - 186s 191ms/step - loss: 0.0015 - accuracy: 0.9994 - val_loss: 2.7333e-04 - val_accuracy: 0.9997 - lr: 1.2500e-04
# Epoch 48/100
# 974/974 [==============================] - ETA: 0s - loss: 0.0018 - accuracy: 0.9994
# Epoch 48: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 974/974 [==============================] - 187s 192ms/step - loss: 0.0018 - accuracy: 0.9994 - val_loss: 6.5783e-04 - val_accuracy: 1.0000 - lr: 1.2500e-04
# Epoch 49/100
# 974/974 [==============================] - 186s 191ms/step - loss: 9.9395e-04 - accuracy: 0.9997 - val_loss: 3.5002e-05 - val_accuracy: 1.0000 - lr: 6.2500e-05
# Epoch 50/100
# 974/974 [==============================] - 186s 191ms/step - loss: 3.8231e-04 - accuracy: 0.9999 - val_loss: 1.0318e-05 - val_accuracy: 1.0000 - lr: 6.2500e-05
# Epoch 51/100
# 974/974 [==============================] - 185s 190ms/step - loss: 8.0571e-04 - accuracy: 0.9997 - val_loss: 1.0885e-05 - val_accuracy: 1.0000 - lr: 6.2500e-05
# Epoch 52/100
# 974/974 [==============================] - 185s 190ms/step - loss: 3.9220e-04 - accuracy: 0.9999 - val_loss: 8.1096e-06 - val_accuracy: 1.0000 - lr: 6.2500e-05
# Epoch 53/100
# 974/974 [==============================] - ETA: 0s - loss: 7.2559e-04 - accuracy: 0.9997
# Epoch 53: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 974/974 [==============================] - 186s 191ms/step - loss: 7.2559e-04 - accuracy: 0.9997 - val_loss: 4.9102e-05 - val_accuracy: 1.0000 - lr: 6.2500e-05
# Epoch 54/100
# 974/974 [==============================] - 186s 191ms/step - loss: 6.5451e-04 - accuracy: 0.9998 - val_loss: 9.9163e-06 - val_accuracy: 1.0000 - lr: 3.1250e-05
# Epoch 55/100
# 974/974 [==============================] - 192s 197ms/step - loss: 9.1206e-04 - accuracy: 0.9997 - val_loss: 9.6657e-06 - val_accuracy: 1.0000 - lr: 3.1250e-05
# Epoch 56/100
# 974/974 [==============================] - 193s 198ms/step - loss: 2.8839e-04 - accuracy: 0.9999 - val_loss: 7.2662e-06 - val_accuracy: 1.0000 - lr: 3.1250e-05
# Epoch 57/100
# 974/974 [==============================] - 187s 192ms/step - loss: 4.3130e-04 - accuracy: 0.9998 - val_loss: 8.0735e-06 - val_accuracy: 1.0000 - lr: 3.1250e-05
# Epoch 58/100
# 974/974 [==============================] - ETA: 0s - loss: 1.8029e-04 - accuracy: 1.0000
# Epoch 58: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 974/974 [==============================] - 190s 196ms/step - loss: 1.8029e-04 - accuracy: 1.0000 - val_loss: 4.7477e-06 - val_accuracy: 1.0000 - lr: 3.1250e-05
# Epoch 59/100
# 974/974 [==============================] - 186s 191ms/step - loss: 3.2362e-04 - accuracy: 0.9999 - val_loss: 4.3580e-06 - val_accuracy: 1.0000 - lr: 1.5625e-05
# Epoch 60/100
# 974/974 [==============================] - 188s 194ms/step - loss: 3.5061e-04 - accuracy: 0.9999 - val_loss: 4.3904e-06 - val_accuracy: 1.0000 - lr: 1.5625e-05
# Epoch 61/100
# 974/974 [==============================] - 187s 192ms/step - loss: 3.7748e-04 - accuracy: 0.9999 - val_loss: 4.0776e-06 - val_accuracy: 1.0000 - lr: 1.5625e-05
# Epoch 62/100
# 974/974 [==============================] - 186s 191ms/step - loss: 7.2701e-04 - accuracy: 0.9999 - val_loss: 4.0288e-06 - val_accuracy: 1.0000 - lr: 1.5625e-05
# Epoch 63/100
# 974/974 [==============================] - ETA: 0s - loss: 1.9708e-04 - accuracy: 0.9999
# Epoch 63: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 974/974 [==============================] - 186s 191ms/step - loss: 1.9708e-04 - accuracy: 0.9999 - val_loss: 3.6357e-06 - val_accuracy: 1.0000 - lr: 1.5625e-05
# Epoch 64/100
# 974/974 [==============================] - 185s 190ms/step - loss: 2.4376e-04 - accuracy: 0.9999 - val_loss: 3.5496e-06 - val_accuracy: 1.0000 - lr: 7.8125e-06
# Epoch 65/100
# 974/974 [==============================] - 186s 191ms/step - loss: 1.1750e-04 - accuracy: 1.0000 - val_loss: 3.3796e-06 - val_accuracy: 1.0000 - lr: 7.8125e-06
# Epoch 66/100
# 974/974 [==============================] - 186s 191ms/step - loss: 1.0260e-04 - accuracy: 1.0000 - val_loss: 3.4484e-06 - val_accuracy: 1.0000 - lr: 7.8125e-06
# Epoch 67/100
# 974/974 [==============================] - 186s 191ms/step - loss: 1.8148e-04 - accuracy: 0.9999 - val_loss: 3.2731e-06 - val_accuracy: 1.0000 - lr: 7.8125e-06
# Epoch 68/100
# 974/974 [==============================] - ETA: 0s - loss: 8.4043e-05 - accuracy: 1.0000
# Epoch 68: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# 974/974 [==============================] - 186s 191ms/step - loss: 8.4043e-05 - accuracy: 1.0000 - val_loss: 3.5473e-06 - val_accuracy: 1.0000 - lr: 7.8125e-06
# Epoch 69/100
# 974/974 [==============================] - 185s 190ms/step - loss: 2.0520e-04 - accuracy: 0.9999 - val_loss: 3.2744e-06 - val_accuracy: 1.0000 - lr: 3.9063e-06
# Epoch 70/100
# 974/974 [==============================] - 186s 191ms/step - loss: 1.4137e-04 - accuracy: 1.0000 - val_loss: 2.8972e-06 - val_accuracy: 1.0000 - lr: 3.9063e-06
# Epoch 71/100
# 974/974 [==============================] - 186s 191ms/step - loss: 7.1863e-05 - accuracy: 1.0000 - val_loss: 3.1277e-06 - val_accuracy: 1.0000 - lr: 3.9063e-06
# Epoch 72/100
# 974/974 [==============================] - 186s 191ms/step - loss: 8.6728e-05 - accuracy: 1.0000 - val_loss: 2.7350e-06 - val_accuracy: 1.0000 - lr: 3.9063e-06
# Epoch 73/100
# 974/974 [==============================] - ETA: 0s - loss: 7.5618e-05 - accuracy: 1.0000
# Epoch 73: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# 974/974 [==============================] - 186s 191ms/step - loss: 7.5618e-05 - accuracy: 1.0000 - val_loss: 2.5301e-06 - val_accuracy: 1.0000 - lr: 3.9063e-06
# Epoch 74/100
# 974/974 [==============================] - 186s 191ms/step - loss: 6.0428e-05 - accuracy: 1.0000 - val_loss: 2.5826e-06 - val_accuracy: 1.0000 - lr: 1.9531e-06
# Epoch 75/100
# 974/974 [==============================] - 186s 191ms/step - loss: 7.1029e-05 - accuracy: 1.0000 - val_loss: 2.5529e-06 - val_accuracy: 1.0000 - lr: 1.9531e-06
# Epoch 76/100
# 974/974 [==============================] - 186s 191ms/step - loss: 2.1551e-04 - accuracy: 0.9999 - val_loss: 2.4861e-06 - val_accuracy: 1.0000 - lr: 1.9531e-06
# Epoch 77/100
# 974/974 [==============================] - 186s 191ms/step - loss: 5.5340e-05 - accuracy: 1.0000 - val_loss: 2.5505e-06 - val_accuracy: 1.0000 - lr: 1.9531e-06
# Epoch 78/100
# 974/974 [==============================] - ETA: 0s - loss: 5.9299e-04 - accuracy: 0.9999
# Epoch 78: ReduceLROnPlateau reducing learning rate to 9.765625463842298e-07.
# 974/974 [==============================] - 186s 191ms/step - loss: 5.9299e-04 - accuracy: 0.9999 - val_loss: 2.4222e-06 - val_accuracy: 1.0000 - lr: 1.9531e-06
# Epoch 79/100
# 974/974 [==============================] - 185s 190ms/step - loss: 2.1382e-04 - accuracy: 0.9999 - val_loss: 2.3386e-06 - val_accuracy: 1.0000 - lr: 9.7656e-07
# Epoch 80/100
# 974/974 [==============================] - 185s 190ms/step - loss: 1.8047e-04 - accuracy: 0.9999 - val_loss: 2.5947e-06 - val_accuracy: 1.0000 - lr: 9.7656e-07
# Epoch 81/100
# 974/974 [==============================] - 185s 190ms/step - loss: 1.4765e-04 - accuracy: 0.9999 - val_loss: 2.4523e-06 - val_accuracy: 1.0000 - lr: 9.7656e-07
# Epoch 82/100
# 974/974 [==============================] - 186s 191ms/step - loss: 7.4299e-05 - accuracy: 1.0000 - val_loss: 2.5128e-06 - val_accuracy: 1.0000 - lr: 9.7656e-07
# Epoch 83/100
# 974/974 [==============================] - ETA: 0s - loss: 1.2478e-04 - accuracy: 0.9999
# Epoch 83: ReduceLROnPlateau reducing learning rate to 4.882812731921149e-07.
# 974/974 [==============================] - 186s 191ms/step - loss: 1.2478e-04 - accuracy: 0.9999 - val_loss: 2.2909e-06 - val_accuracy: 1.0000 - lr: 9.7656e-07
# Epoch 84/100
# 974/974 [==============================] - 186s 191ms/step - loss: 1.3629e-04 - accuracy: 1.0000 - val_loss: 2.2737e-06 - val_accuracy: 1.0000 - lr: 4.8828e-07
# Epoch 85/100
# 974/974 [==============================] - 186s 191ms/step - loss: 1.0848e-04 - accuracy: 1.0000 - val_loss: 2.2604e-06 - val_accuracy: 1.0000 - lr: 4.8828e-07
# Epoch 86/100
# 974/974 [==============================] - 186s 191ms/step - loss: 8.0550e-05 - accuracy: 1.0000 - val_loss: 2.4625e-06 - val_accuracy: 1.0000 - lr: 4.8828e-07
# Epoch 87/100
# 974/974 [==============================] - 187s 192ms/step - loss: 1.8072e-04 - accuracy: 0.9999 - val_loss: 2.2256e-06 - val_accuracy: 1.0000 - lr: 4.8828e-07
# Epoch 88/100
# 974/974 [==============================] - ETA: 0s - loss: 1.8540e-04 - accuracy: 0.9999
# Epoch 88: ReduceLROnPlateau reducing learning rate to 2.4414063659605745e-07.
# 974/974 [==============================] - 186s 191ms/step - loss: 1.8540e-04 - accuracy: 0.9999 - val_loss: 2.3629e-06 - val_accuracy: 1.0000 - lr: 4.8828e-07
# Epoch 89/100
# 974/974 [==============================] - 186s 191ms/step - loss: 0.0010 - accuracy: 0.9999 - val_loss: 2.0947e-06 - val_accuracy: 1.0000 - lr: 2.4414e-07
# Epoch 90/100
# 974/974 [==============================] - 186s 191ms/step - loss: 6.2367e-05 - accuracy: 1.0000 - val_loss: 2.4596e-06 - val_accuracy: 1.0000 - lr: 2.4414e-07
# Epoch 91/100
# 974/974 [==============================] - 186s 191ms/step - loss: 1.1627e-04 - accuracy: 0.9999 - val_loss: 2.2850e-06 - val_accuracy: 1.0000 - lr: 2.4414e-07
# Epoch 92/100
# 974/974 [==============================] - 186s 191ms/step - loss: 6.5474e-05 - accuracy: 1.0000 - val_loss: 2.2754e-06 - val_accuracy: 1.0000 - lr: 2.4414e-07
# Epoch 93/100
# 974/974 [==============================] - ETA: 0s - loss: 6.2084e-05 - accuracy: 1.0000
# Epoch 93: ReduceLROnPlateau reducing learning rate to 1.2207031829802872e-07.
# 974/974 [==============================] - 186s 191ms/step - loss: 6.2084e-05 - accuracy: 1.0000 - val_loss: 2.2646e-06 - val_accuracy: 1.0000 - lr: 2.4414e-07
# Epoch 94/100
# 974/974 [==============================] - 185s 190ms/step - loss: 1.0098e-04 - accuracy: 1.0000 - val_loss: 2.2061e-06 - val_accuracy: 1.0000 - lr: 1.2207e-07
# Epoch 95/100
# 974/974 [==============================] - 185s 190ms/step - loss: 1.6562e-04 - accuracy: 0.9999 - val_loss: 2.2537e-06 - val_accuracy: 1.0000 - lr: 1.2207e-07
# Epoch 96/100
# 974/974 [==============================] - 185s 190ms/step - loss: 5.3260e-05 - accuracy: 1.0000 - val_loss: 2.2338e-06 - val_accuracy: 1.0000 - lr: 1.2207e-07
# Epoch 97/100
# 974/974 [==============================] - ETA: 0s - loss: 5.6839e-04 - accuracy: 0.9999Restoring model weights from the end of the best epoch: 89.
# 974/974 [==============================] - 186s 190ms/step - loss: 5.6839e-04 - accuracy: 0.9999 - val_loss: 2.1546e-06 - val_accuracy: 1.0000 - lr: 1.2207e-07
# Epoch 97: early stopping
#
# Training Time: 18065.55 seconds
# Testing Time: 46.16 seconds
# Test Accuracy: 0.936
#
# Confusion Matrix (Percentage) for ResNet101:
# [[90.28776978  3.77697842  4.13669065  1.07913669  0.17985612  0.35971223
#    0.17985612]
#  [ 9.72972973 87.56756757  2.52252252  0.18018018  0.          0.
#    0.        ]
#  [ 6.65467626  3.05755396 89.56834532  0.53956835  0.17985612  0.
#    0.        ]
#  [ 2.52707581  0.36101083  1.26353791 95.12635379  0.36101083  0.18050542
#    0.18050542]
#  [ 0.72072072  0.54054054  1.62162162  0.54054054 96.57657658  0.
#    0.        ]
#  [ 0.9009009   0.36036036  0.18018018  0.18018018  0.         98.37837838
#    0.        ]
#  [ 0.89766607  0.17953321  0.35906643  0.53859964  0.17953321  0.
#   97.84560144]]
#
# Classification Report for ResNet101:
#               precision    recall  f1-score   support
#
#            0      0.808     0.903     0.853       556
#            1      0.914     0.876     0.894       555
#            2      0.899     0.896     0.897       556
#            3      0.969     0.951     0.960       554
#            4      0.991     0.966     0.978       555
#            5      0.995     0.984     0.989       555
#            6      0.996     0.978     0.987       557
#
#     accuracy                          0.936      3888
#    macro avg      0.939     0.936     0.937      3888
# weighted avg      0.939     0.936     0.937      3888
# ==================================================
# Training EfficientNet-B0
# ==================================================
# Epoch 1/100
# 974/974 [==============================] - 116s 112ms/step - loss: 0.3572 - accuracy: 0.8803 - val_loss: 150.3104 - val_accuracy: 0.1463 - lr: 0.0010
# Epoch 2/100
# 974/974 [==============================] - 107s 110ms/step - loss: 0.2310 - accuracy: 0.9185 - val_loss: 5.6388 - val_accuracy: 0.1459 - lr: 0.0010
# Epoch 3/100
# 974/974 [==============================] - 107s 109ms/step - loss: 0.2075 - accuracy: 0.9257 - val_loss: 108.2769 - val_accuracy: 0.1253 - lr: 0.0010
# Epoch 4/100
# 974/974 [==============================] - 107s 110ms/step - loss: 0.2068 - accuracy: 0.9294 - val_loss: 11.1433 - val_accuracy: 0.1485 - lr: 0.0010
# Epoch 5/100
# 974/974 [==============================] - 107s 110ms/step - loss: 0.1761 - accuracy: 0.9355 - val_loss: 80.8392 - val_accuracy: 0.1405 - lr: 0.0010
# Epoch 6/100
# 974/974 [==============================] - 108s 110ms/step - loss: 0.1832 - accuracy: 0.9343 - val_loss: 7.7113 - val_accuracy: 0.1485 - lr: 0.0010
# Epoch 7/100
# 974/974 [==============================] - 108s 111ms/step - loss: 0.1655 - accuracy: 0.9414 - val_loss: 4.9366 - val_accuracy: 0.1527 - lr: 0.0010
# Epoch 8/100
# 974/974 [==============================] - 107s 110ms/step - loss: 0.1519 - accuracy: 0.9462 - val_loss: 5.8032 - val_accuracy: 0.1553 - lr: 0.0010
# Epoch 9/100
# 974/974 [==============================] - 108s 111ms/step - loss: 0.1446 - accuracy: 0.9487 - val_loss: 4.8511 - val_accuracy: 0.1456 - lr: 0.0010
# Epoch 10/100
# 974/974 [==============================] - 107s 110ms/step - loss: 0.1372 - accuracy: 0.9510 - val_loss: 6.5023 - val_accuracy: 0.1472 - lr: 0.0010
# Epoch 11/100
# 974/974 [==============================] - 107s 110ms/step - loss: 0.1178 - accuracy: 0.9588 - val_loss: 6.4090 - val_accuracy: 0.1453 - lr: 0.0010
# Epoch 12/100
# 974/974 [==============================] - 107s 110ms/step - loss: 0.1080 - accuracy: 0.9628 - val_loss: 7.9447 - val_accuracy: 0.1459 - lr: 0.0010
# Epoch 13/100
# 974/974 [==============================] - 107s 110ms/step - loss: 0.0944 - accuracy: 0.9676 - val_loss: 5.6061 - val_accuracy: 0.1482 - lr: 0.0010
# Epoch 14/100
# 974/974 [==============================] - ETA: 0s - loss: 0.0992 - accuracy: 0.9671
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 974/974 [==============================] - 107s 110ms/step - loss: 0.0992 - accuracy: 0.9671 - val_loss: 6.8765 - val_accuracy: 0.1492 - lr: 0.0010
# Epoch 15/100
# 974/974 [==============================] - 107s 110ms/step - loss: 0.0440 - accuracy: 0.9855 - val_loss: 6.3455 - val_accuracy: 0.1495 - lr: 5.0000e-04
# Epoch 16/100
# 974/974 [==============================] - 107s 110ms/step - loss: 0.0285 - accuracy: 0.9905 - val_loss: 7.4530 - val_accuracy: 0.2068 - lr: 5.0000e-04
# Epoch 17/100
# 974/974 [==============================] - ETA: 0s - loss: 0.0270 - accuracy: 0.9908Restoring model weights from the end of the best epoch: 9.
# 974/974 [==============================] - 107s 110ms/step - loss: 0.0270 - accuracy: 0.9908 - val_loss: 7.1040 - val_accuracy: 0.1611 - lr: 5.0000e-04
# Epoch 17: early stopping
#
# Training Time: 1831.30 seconds
# Testing Time: 36.23 seconds
# Test Accuracy: 0.143
#
# Confusion Matrix (Percentage) for EfficientNet-B0:
# [[100.   0.   0.   0.   0.   0.   0.]
#  [100.   0.   0.   0.   0.   0.   0.]
#  [100.   0.   0.   0.   0.   0.   0.]
#  [100.   0.   0.   0.   0.   0.   0.]
#  [100.   0.   0.   0.   0.   0.   0.]
#  [100.   0.   0.   0.   0.   0.   0.]
#  [100.   0.   0.   0.   0.   0.   0.]]
#
# Classification Report for EfficientNet-B0:
#               precision    recall  f1-score   support
#
#            0      0.142     1.000     0.249       554
#            1      0.000     0.000     0.000       556
#            2      0.000     0.000     0.000       557
#            3      0.000     0.000     0.000       556
#            4      0.000     0.000     0.000       555
#            5      0.000     0.000     0.000       555
#            6      0.000     0.000     0.000       555
#
#     accuracy                          0.142      3888
#    macro avg      0.020     0.143     0.036      3888
# weighted avg      0.020     0.142     0.036      3888
# c:\Users\abdur\miniconda3\envs\tf\lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\abdur\miniconda3\envs\tf\lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\abdur\miniconda3\envs\tf\lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# ============================================================
# SUMMARY OF ALL MODELS
# ============================================================
# Custom CNN      | Accuracy: 0.946 | Train Time: 1095.27s | Test Time: 28.69s
# ResNet50        | Accuracy: 0.937 | Train Time: 5727.26s | Test Time: 38.92s
# ResNet101       | Accuracy: 0.936 | Train Time: 18065.55s | Test Time: 46.16s
# EfficientNet-B0 | Accuracy: 0.143 | Train Time: 1831.30s | Test Time: 36.23s
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
